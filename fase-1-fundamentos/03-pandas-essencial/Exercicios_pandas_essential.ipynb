# %% [markdown]
# ### Exercicio 1

# %%
import numpy as np
import pandas as pd

# %%
lista = ['a', 'b', 'c', 'd']
series = pd.Series(lista)

# %%
series
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: str

# %%
lista = ['a', 'b', 'c', 'd']
series = pd.Series(lista,np.arange(10,14))
series
# Out:
# 10    a
# 11    b
# 12    c
# 13    d
# dtype: str

# %%
lista = [10, 10, 10, 10]
series = pd.Series(lista)
serie3 = pd.Series(10,index=[0,1,2,3])
serie3
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# dtype: int64

# %%
array = np.arange(10,20,2)
serie4 = pd.Series(array, index=range(1,6), dtype=float)
serie4
# Out:
# 1    10.0
# 2    12.0
# 3    14.0
# 4    16.0
# 5    18.0
# dtype: float64

# %% [markdown]
# ### Exercício 2

# %%
data = ['k','w','z','y']
serie4 = pd.Series(data,dtype=object)
serie4
# Out:
# 0    k
# 1    w
# 2    z
# 3    y
# dtype: object

# %%
dic = {'a':10,'b':30,'c':15,'d':12}
serie = pd.Series(dic)
serie
# Out:
# a    10
# b    30
# c    15
# d    12
# dtype: int64

# %%
data_list = serie4.to_list()
data_list
# Out:
# ['k', 'w', 'z', 'y']

# %%
dic_list = serie.to_list()
dic_list
# Out:
# [10, 30, 15, 12]

# %%
serie4 = pd.DataFrame(serie4,columns=[ "Letras"])
serie4
# Out:
#   Letras
# 0      k
# 1      w
# 2      z
# 3      y

# %%
serie = pd.DataFrame(serie,columns=["Valores"])
serie
# Out:
#    Valores
# a       10
# b       30
# c       15
# d       12

# %% [markdown]
# ### Exercício 3

# %%
serie = pd.Series(data=np.arange(1,51,2),name="Series",index=np.arange(25,50),dtype=float)
serie
# Out:
# 25     1.0
# 26     3.0
# 27     5.0
# 28     7.0
# 29     9.0
# 30    11.0
# 31    13.0
# 32    15.0
# 33    17.0
# 34    19.0
# 35    21.0
# 36    23.0
# 37    25.0
# 38    27.0
# 39    29.0
# 40    31.0
# 41    33.0
# 42    35.0
# 43    37.0
# 44    39.0
# 45    41.0
# 46    43.0
# 47    45.0
# 48    47.0
# 49    49.0
# Name: Series, dtype: float64

# %% [markdown]
# ### Exercício 4

# %%
data = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']
serie = pd.Series(data,index=np.arange(1,6))
serie
# Out:
# 1     ITUB4
# 2     BBDC4
# 3     BBAS3
# 4    BPAC11
# 5    SANB11
# dtype: str

# %%
dic = serie.to_dict()
dic
# Out:
# {1: 'ITUB4', 2: 'BBDC4', 3: 'BBAS3', 4: 'BPAC11', 5: 'SANB11'}

# %%
lista = serie.to_list()
lista
# Out:
# ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']

# %%
array = serie.to_numpy()
array
# Out:
# array(['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11'], dtype=object)

# %% [markdown]
# ### Exercício 5

# %%
dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }

serie = pd.Series(dados)
serie
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# dtype: float64

# %%
lista = serie.to_list()
lista
# Out:
# [12.85, 22.55, 115.08, 49.03, 24.41]

# %%
df = pd.DataFrame(serie,columns=["Preços"])
df
# Out:
#        Preços
# ABEV3   12.85
# AZUL4   22.55
# BTOW3  115.08
# RENT3   49.03
# JBSS3   24.41

# %%
serie['RAIL3'] = 18.93
serie['JBSS3'] = 21.48
serie['SUZB3'] = 48.19
serie['MGLU3'] = 25.59

# %%
serie
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     21.48
# RAIL3     18.93
# SUZB3     48.19
# MGLU3     25.59
# dtype: float64

# %% [markdown]
# ### Exercício 6

# %%
dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }
serie = pd.Series(dados,dtype=float)
serie
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# dtype: float64

# %%
serie['PETR4'] = 22.97
serie['NTCO3'] = 50.60
serie['TIMP3'] = 14.82

# %%
serie
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# PETR4     22.97
# NTCO3     50.60
# TIMP3     14.82
# dtype: float64

# %% [markdown]
# ### Exercício 7

# %%
serie = pd.Series(data=np.arange(1,21,2),index = [chr(65+i) for i in range(10)])
serie
# Out:
# A     1
# B     3
# C     5
# D     7
# E     9
# F    11
# G    13
# H    15
# I    17
# J    19
# dtype: int64

# %%
serie = pd.Series(data=np.arange(5,50,5),index = [chr(70+i) for i in range(9)])
serie
# Out:
# F     5
# G    10
# H    15
# I    20
# J    25
# K    30
# L    35
# M    40
# N    45
# dtype: int64

# %% [markdown]
# ### Exercício 8

# %%
anos = list(range(1900,2021,10))
valores = [i**3 for i in range(1,14)]
series = pd.Series(data = valores, index = anos, name = 'Crescimento no tempo')[::-1]
series
# Out:
# 2020    2197
# 2010    1728
# 2000    1331
# 1990    1000
# 1980     729
# 1970     512
# 1960     343
# 1950     216
# 1940     125
# 1930      64
# 1920      27
# 1910       8
# 1900       1
# Name: Crescimento no tempo, dtype: int64

# %%
series.plot(title = 'Taxa de Crescimento no Tempo');

# %% [markdown]
# ### Exercício 9

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
print(f'Primeiro elemento: {s.iloc[0]}')
print(f'Terceiro elemento: {s.iloc[2]}')
print(f'Três primeiros elementos: \n{s.iloc[:3]}')
print(f'Três últimos elementos: \n{s.iloc[-3:]}')
print(f'Último elemento: {s.iloc[-1]}')
# Out:
# Primeiro elemento: 1
# Terceiro elemento: 3
# Três primeiros elementos:
# a    1
# b    2
# c    3
# dtype: int64
# Três últimos elementos:
# d    4
# e    5
# f    6
# dtype: int64
# Último elemento: 6

# %% [markdown]
# ### Exercício 10

# %%
s = pd.Series(np.random.randn(5))
print(s.axes)
print(s.empty)
print(s.ndim)
print(s.size)
print(s.values)
# Out:
# [RangeIndex(start=0, stop=5, step=1)]
# False
# 1
# 5
# [ 0.27877539  0.34206326 -0.77260774  0.62169412 -1.10182299]

# %% [markdown]
# ### Exercício 11

# %%
dados = [10, 22, 3, 11, 17, 22, 9, 4, 29, 31]
df = pd.DataFrame(data = dados, columns = ['A'])
df
# Out:
#     A
# 0  10
# 1  22
# 2   3
# 3  11
# 4  17
# 5  22
# 6   9
# 7   4
# 8  29
# 9  31

# %% [markdown]
# ### Exercício 12

# %%
dic = {'A': [11, 33, 11, -1, 0],
      'B': [1, 2, 3, 4, 5],
      'C': [130, 144, 111, 104, 199]}
df = pd.DataFrame(dic)
df
# Out:
#     A  B    C
# 0  11  1  130
# 1  33  2  144
# 2  11  3  111
# 3  -1  4  104
# 4   0  5  199

# %% [markdown]
# ### Exercício 13

# %%
dados = {
    'A': [i for i in range(1,21) if i%2==0],
    'B': [i**3 for i in range(1,21) if i%2!=0]
        }
df = pd.DataFrame(dados, index = range(1, len(dados['A'])+1))
df
# Out:
#      A     B
# 1    2     1
# 2    4    27
# 3    6   125
# 4    8   343
# 5   10   729
# 6   12  1331
# 7   14  2197
# 8   16  3375
# 9   18  4913
# 10  20  6859

# %% [markdown]
# ### Exercício 14

# %%
dados = {
    'A': [i for i in range(1,21) if i%2==0],
    'B': [i**3 for i in range(1,21) if i%2!=0],
    'C': [i**2 for i in range(1,21) if i%2!=0]
        }
df = pd.DataFrame(dados, index = range(1, len(dados['A'])+1))
df
# Out:
#      A     B    C
# 1    2     1    1
# 2    4    27    9
# 3    6   125   25
# 4    8   343   49
# 5   10   729   81
# 6   12  1331  121
# 7   14  2197  169
# 8   16  3375  225
# 9   18  4913  289
# 10  20  6859  361

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Exercício 15

# %%
array = np.random.normal(800, 30, size = (10, 4)).round(2)
anos = range(2010, 2020)
colunas = ['A', 'B', 'C' , 'D']
df = pd.DataFrame(data = array, index = anos, columns = colunas)
df.columns.name = 'Produtos'
df.index.name = 'Anos'
df.plot();

# %% [markdown]
# ### Exercicio 16

# %%
index = ['Produto '+str(i) for i in range(1,9)]
dados = {
    'Preço': [20.3, 31.2, 44.7, 30.5, 19.8, 11.2, 15.7, 17.3],
    'Quantidade': [10, 33, 45, 51, 11, 8, 91, 8],
    'Custo Total': [100, 568.7, 205.2, 507.1, 250.12, 55.3, 1579, 130]}
df = pd.DataFrame(dados, index)

# %%
df
# Out:
#            Preço  Quantidade  Custo Total
# Produto 1   20.3          10       100.00
# Produto 2   31.2          33       568.70
# Produto 3   44.7          45       205.20
# Produto 4   30.5          51       507.10
# Produto 5   19.8          11       250.12
# Produto 6   11.2           8        55.30
# Produto 7   15.7          91      1579.00
# Produto 8   17.3           8       130.00

# %% [markdown]
# ### Exercício 17

# %%
df['Receita Total'] = df['Preço']*df['Quantidade']
df['Lucro Total'] = df['Receita Total']-df['Custo Total']
df
# Out:
#            Preço  Quantidade  Custo Total  Receita Total  Lucro Total
# Produto 1   20.3          10       100.00          203.0       103.00
# Produto 2   31.2          33       568.70         1029.6       460.90
# Produto 3   44.7          45       205.20         2011.5      1806.30
# Produto 4   30.5          51       507.10         1555.5      1048.40
# Produto 5   19.8          11       250.12          217.8       -32.32
# Produto 6   11.2           8        55.30           89.6        34.30
# Produto 7   15.7          91      1579.00         1428.7      -150.30
# Produto 8   17.3           8       130.00          138.4         8.40

# %% [markdown]
# ### Exercício 18

# %%
array = np.random.random(50).reshape((10,5))
columns = list('ABCDE')
array
# Out:
# array([[0.2469793 , 0.40897761, 0.66688536, 0.08037965, 0.48480312],
#        [0.63070103, 0.37920028, 0.764404  , 0.85571619, 0.82473359],
#        [0.79322202, 0.93660378, 0.97439069, 0.85345416, 0.22230101],
#        [0.34542431, 0.04099936, 0.93170065, 0.69809025, 0.71459343],
#        [0.36897806, 0.98266724, 0.54865175, 0.73435422, 0.95375728],
#        [0.24247919, 0.00637896, 0.91300046, 0.32898799, 0.52939886],
#        [0.54852557, 0.66031696, 0.61805269, 0.70232578, 0.61398229],
#        [0.61803937, 0.01806525, 0.19254639, 0.61012251, 0.30491961],
#        [0.22144391, 0.19200194, 0.20542019, 0.80987215, 0.79365831],
#        [0.44885051, 0.78320383, 0.21829123, 0.5871937 , 0.40272271]])

# %%
df = pd.DataFrame(array,index=range(1,11),columns=columns)
df
# Out:
#            A         B         C         D         E
# 1   0.246979  0.408978  0.666885  0.080380  0.484803
# 2   0.630701  0.379200  0.764404  0.855716  0.824734
# 3   0.793222  0.936604  0.974391  0.853454  0.222301
# 4   0.345424  0.040999  0.931701  0.698090  0.714593
# 5   0.368978  0.982667  0.548652  0.734354  0.953757
# 6   0.242479  0.006379  0.913000  0.328988  0.529399
# 7   0.548526  0.660317  0.618053  0.702326  0.613982
# 8   0.618039  0.018065  0.192546  0.610123  0.304920
# 9   0.221444  0.192002  0.205420  0.809872  0.793658
# 10  0.448851  0.783204  0.218291  0.587194  0.402723

# %% [markdown]
# ### Exercício 19

# %%
produtos = {
    'produto1': {2008:7, 2009:9, 2010: 10, 2011: 15, 2012: 50, 2013: 47}, 
    'produto2': {2008:14, 2009:13, 2010: 7, 2011: 13, 2012: 77, 2013: 94}, 
    'produto3': {2008:5, 2009:11, 2010: 3, 2011: 45, 2012: 21, 2013: 33},
    'produto4': {2008:4, 2009:2, 2010: 3, 2011: 45, 2012: 21, 2013: 33}}
df = pd.DataFrame(produtos)
df.columns.name='produtos'
df.index.name='Ano'

# %%
df
# Out:
# produtos  produto1  produto2  produto3  produto4
# Ano
# 2008             7        14         5         4
# 2009             9        13        11         2
# 2010            10         7         3         3
# 2011            15        13        45        45
# 2012            50        77        21        21
# 2013            47        94        33        33

# %% [markdown]
# ### Exercício 20

# %%
dados = {
    'Cliente': ['Jéssica', 'Carlos', 'Rafael', 'João', 'Pedro', 'Júnior', 'Laís', 'Tales'],
    'Idade': [36, 39, 33, 32, 27, 35, 28, 18],
    'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66] 
}
df = pd.DataFrame(dados)
df
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56
# 3     João     32    8.32
# 4    Pedro     27    9.15
# 5   Júnior     35    1.34
# 6     Laís     28    0.57
# 7    Tales     18    1.66

# %%
df.head()
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56
# 3     João     32    8.32
# 4    Pedro     27    9.15

# %%
df.head(3)
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56

# %%
df.tail()
# Out:
#   Cliente  Idade  Rating
# 3    João     32    8.32
# 4   Pedro     27    9.15
# 5  Júnior     35    1.34
# 6    Laís     28    0.57
# 7   Tales     18    1.66

# %%
df.tail(2)
# Out:
#   Cliente  Idade  Rating
# 6    Laís     28    0.57
# 7   Tales     18    1.66

# %% [markdown]
# ### Exercício 21

# %%
nomes = ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales']
notas = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
aprovado = ['Sim' if nota>=7 else 'Não' for nota in notas]
dados = {
    'Nome': nomes,
    'Nota': notas,
    'Resultado Final': aprovado 
}
df = pd.DataFrame(dados)
df
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 2  Rogério   4.7             Não
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não
# 6   Milena   5.0             Não
# 7    Tales   7.7             Sim

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome             8 non-null      str
#  1   Nota             8 non-null      float64
#  2   Resultado Final  8 non-null      str
# dtypes: float64(1), str(2)
# memory usage: 324.0 bytes
# None

# %% [markdown]
# ### Exercício 22

# %%
df.describe()
# Out:
#            Nota
# count   8.00000
# mean    7.23750
# std     1.94858
# min     4.70000
# 25%     5.75000
# 50%     7.35000
# 75%     8.37500
# max    10.00000

# %%
print(df["Nota"].max())
print(df["Nota"].min())
# Out:
# 10.0
# 4.7

# %%
aprovados = df[df['Nota'] >= 7]

# %%
aprovados
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 7    Tales   7.7             Sim

# %%
aprovados = df[df['Resultado Final'] == 'Sim']

# %%
aprovados
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 7    Tales   7.7             Sim

# %% [markdown]
# ### Exercício 23

# %%
dados = np.random.uniform(low = 0, high = 5, size = (100,5))
df = pd.DataFrame(dados, 
                  index = range(1,dados.shape[0]+1), 
                  columns = list('ABCDE'))
df = pd.DataFrame(dados)

# %%
df
# Out:
#            0         1         2         3         4
# 0   0.231529  4.573124  3.530664  0.006753  2.955326
# 1   0.481021  1.411805  2.661882  3.414946  2.514866
# 2   1.350210  0.594946  3.523526  2.851701  2.949507
# 3   3.922078  0.734672  4.032453  3.135551  3.907306
# 4   4.069899  1.754868  3.636815  2.082251  3.763585
# ..       ...       ...       ...       ...       ...
# 95  3.937902  1.277955  4.746940  2.436403  1.379219
# 96  3.134030  2.933608  0.621782  3.759480  3.438826
# 97  4.441346  4.328672  4.115508  2.906028  3.088709
# 98  0.208207  0.608502  2.419214  2.917968  4.270243
# 99  4.501925  0.608751  0.518028  2.473630  0.499699
#
# [100 rows x 5 columns]

# %%
print(f'Número de linhas: {df.shape[0]}')
print(f'Número de colunas: {df.shape[1]}')
print(f'Shape: {df.shape}')
print(f'Número total de elementos: {df.size}')
print(f'Número de dimensões: {df.ndim}')
print('-'*100)
print(f'Informações do dataset:')
print(df.info())
print('-'*100)
print(f'Dtype de cada coluna: \n{df.dtypes}')
print('-'*100)
print(f'Estatísticas descritivas: \n{df.describe()}')
# Out:
# Número de linhas: 100
# Número de colunas: 5
# Shape: (100, 5)
# Número total de elementos: 500
# Número de dimensões: 2
# ----------------------------------------------------------------------------------------------------
# Informações do dataset:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       100 non-null    float64
#  1   1       100 non-null    float64
#  2   2       100 non-null    float64
#  3   3       100 non-null    float64
#  4   4       100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB
# None
# ----------------------------------------------------------------------------------------------------
# Dtype de cada coluna:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object
# ----------------------------------------------------------------------------------------------------
# Estatísticas descritivas:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     2.485209    2.563658    2.544686    2.571246    2.414670
# std      1.527514    1.514987    1.421564    1.533720    1.490976
# min      0.036575    0.007048    0.013281    0.006753    0.003652
# 25%      1.165343    1.391293    1.341346    1.163181    1.214956
# 50%      2.611906    2.288927    2.660696    2.631362    2.357329
# 75%      3.844147    4.088701    3.672019    4.015572    3.664738
# max      4.935503    4.943762    4.946630    4.984242    4.973639

# %% [markdown]
# ### Exercício 24

# %%
dic = {
    'A': [11, 3, 7, 99, 100, 130, 150],
    'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],
    'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],
    'D': [True, False, True, False, True, False, True],    
    'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],
    'F': [True, True, False, False, True, False, True],}

index = list(range(10, 71, 10))
df = pd.DataFrame(data = dic, index = index)

# %%
df
# Out:
#       A    B  C      D  E      F
# 10   11  1.2  A   True  A   True
# 20    3  0.5  Z  False  A   True
# 30    7  1.2  W   True  B  False
# 40   99  3.2  K  False  B  False
# 50  100  0.9  A   True  A   True
# 60  130  1.7  Z  False  A  False
# 70  150  9.5  Z   True  B   True

# %%
print(f'Dtype de cada coluna: \n{df.dtypes}')
# Out:
# Dtype de cada coluna:
# A      int64
# B    float64
# C        str
# D       bool
# E        str
# F       bool
# dtype: object

# %%
df[['C','E']] = df[['C', 'E']].astype('category')  #convertendo o dtype das colunas 'C' e 'E'

# %%
print(f"Colunas do tipo category: \n{df.select_dtypes('category')}")
print(f'Colunas do tipo bool: \n{df.select_dtypes(bool)}')
print(f'Colunas numéricas: \n{df.select_dtypes(include = [float, int])}')
print(df.describe(include = 'all').T)
# Out:
# Colunas do tipo category:
#     C  E
# 10  A  A
# 20  Z  A
# 30  W  B
# 40  K  B
# 50  A  A
# 60  Z  A
# 70  Z  B
# Colunas do tipo bool:
#         D      F
# 10   True   True
# 20  False   True
# 30   True  False
# 40  False  False
# 50   True   True
# 60  False  False
# 70   True   True
# Colunas numéricas:
#       A    B
# 10   11  1.2
# 20    3  0.5
# 30    7  1.2
# 40   99  3.2
# 50  100  0.9
# 60  130  1.7
# 70  150  9.5
#   count unique   top freq       mean        std  min   25%   50%    75%    max
# A   7.0    NaN   NaN  NaN  71.428571  62.803549  3.0   9.0  99.0  115.0  150.0
# B   7.0    NaN   NaN  NaN        2.6   3.162278  0.5  1.05   1.2   2.45    9.5
# C     7      4     Z    3        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# D     7      2  True    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# E     7      2     A    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# F     7      2  True    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN

# %% [markdown]
# ### Exercício 25

# %%
array = np.random.normal(10, 0.5, (10,10)).round(1)
col = [chr(64+i) for i in range(1, array.shape[1]+1)]
index = [chr(64+i)+str(i) for i in range(1,array.shape[0]+1)]
df = pd.DataFrame(data = array, columns = col, index= index)
df
# Out:
#         A     B     C     D     E     F     G     H     I     J
# A1    9.5  10.7  11.1  10.7   9.7   9.7  10.4  10.4  10.3  10.4
# B2   10.9  10.9  10.6   9.6  10.6   9.9   9.7  10.8   9.9  10.7
# C3    9.7  10.0  10.5   9.6  10.4   9.5  10.0  10.0  10.8  10.7
# D4    9.3  10.3  11.5  10.4  10.8   9.4  10.0   9.1  10.0  10.4
# E5    9.7  10.2  10.8  10.1  10.4   9.8   9.5  10.4   9.8  10.1
# F6    9.4   9.4  10.2   9.6  10.8   9.9   9.5  10.8  10.2  11.2
# G7    9.5  10.3  10.0  10.3  10.2   9.3  10.0  10.5   9.0  10.4
# H8    9.5  10.0   9.5   9.7   9.4  10.0  10.2   9.7  11.2   9.8
# I9    9.5   9.7  10.0  11.4  10.4  10.5   9.8  10.9  10.4  10.9
# J10   9.8   9.2   9.4  10.3   9.4   8.5  10.8   9.4  10.5  10.8

# %% [markdown]
# ### Exercício 26

# %%
notas = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
dados = {
    'Nome': ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales'],
    'Nota': [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7],
    'Resultado Final': ['Sim' if nota>=7 else 'Não' for nota in notas]
}
df = pd.DataFrame(dados)

# %%
df1 = df['Nome']
df1
# Out:
# 0     Carlos
# 1     Rafael
# 2    Rogério
# 3        Ana
# 4    Beatriz
# 5      Jorge
# 6     Milena
# 7      Tales
# Name: Nome, dtype: str

# %%
df2 = df['Resultado Final']
df2
# Out:
# 0    Sim
# 1    Sim
# 2    Não
# 3    Sim
# 4    Sim
# 5    Não
# 6    Não
# 7    Sim
# Name: Resultado Final, dtype: str

# %%
print(df[['Nome','Resultado Final']])
# Out:
#       Nome Resultado Final
# 0   Carlos             Sim
# 1   Rafael             Sim
# 2  Rogério             Não
# 3      Ana             Sim
# 4  Beatriz             Sim
# 5    Jorge             Não
# 6   Milena             Não
# 7    Tales             Sim

# %%
print(df.iloc[6:7])
print(df.iloc[3:6])
# Out:
#      Nome  Nota Resultado Final
# 6  Milena   5.0             Não
#       Nome  Nota Resultado Final
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não

# %% [markdown]
# ### Exercício 27

# %%
df
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 2  Rogério   4.7             Não
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não
# 6   Milena   5.0             Não
# 7    Tales   7.7             Sim

# %%
print(df.Nome[1:4].to_list())
# Out:
# ['Rafael', 'Rogério', 'Ana']

# %%
print(df.Nome.loc[[0,2,7]].tolist())
# Out:
# ['Carlos', 'Rogério', 'Tales']

# %%
print(df.Nome.iloc[0:1][0])
# Out:
# Carlos

# %%
print(df.Nota.iloc[-1])
# Out:
# 7.7

# %%
print(df.Nota[0])
# Out:
# 7.0

# %% [markdown]
# ### Exercício 28

# %%
dados = np.random.randint(1,50,16,).reshape((4,4))
index = ['Ano '+str(i) for i in range(1,5)]
col = ['Marca '+chr(65+i) for i in range(4)]
df = pd.DataFrame(dados, columns = col, index= index )

# %%
df
# Out:
#        Marca A  Marca B  Marca C  Marca D
# Ano 1       36       42       15       19
# Ano 2       48       19       38       40
# Ano 3       12        6       43       28
# Ano 4       40        7        5        8

# %%
df.columns
# Out:
# Index(['Marca A', 'Marca B', 'Marca C', 'Marca D'], dtype='str')

# %%
df.index
# Out:
# Index(['Ano 1', 'Ano 2', 'Ano 3', 'Ano 4'], dtype='str')

# %%
df.shape
# Out:
# (4, 4)

# %%
df.values
# Out:
# array([[36, 42, 15, 19],
#        [48, 19, 38, 40],
#        [12,  6, 43, 28],
#        [40,  7,  5,  8]], dtype=int32)

# %%
df['Marca A']
# Out:
# Ano 1    36
# Ano 2    48
# Ano 3    12
# Ano 4    40
# Name: Marca A, dtype: int32

# %%
df['Marca C']
# Out:
# Ano 1    15
# Ano 2    38
# Ano 3    43
# Ano 4     5
# Name: Marca C, dtype: int32

# %%
df.describe()
# Out:
#          Marca A    Marca B    Marca C    Marca D
# count   4.000000   4.000000   4.000000   4.000000
# mean   34.000000  18.500000  25.250000  23.750000
# std    15.491933  16.743158  18.191115  13.573872
# min    12.000000   6.000000   5.000000   8.000000
# 25%    30.000000   6.750000  12.500000  16.250000
# 50%    38.000000  13.000000  26.500000  23.500000
# 75%    42.000000  24.750000  39.250000  31.000000
# max    48.000000  42.000000  43.000000  40.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, Ano 1 to Ano 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Marca A  4 non-null      int32
#  1   Marca B  4 non-null      int32
#  2   Marca C  4 non-null      int32
#  3   Marca D  4 non-null      int32
# dtypes: int32(4)
# memory usage: 268.0+ bytes

# %%
df.dtypes
# Out:
# Marca A    int32
# Marca B    int32
# Marca C    int32
# Marca D    int32
# dtype: object

# %%
df = df.astype(float)
df.dtypes
# Out:
# Marca A    float64
# Marca B    float64
# Marca C    float64
# Marca D    float64
# dtype: object

# %%
df.loc['Ano 1']
# Out:
# Marca A    36.0
# Marca B    42.0
# Marca C    15.0
# Marca D    19.0
# Name: Ano 1, dtype: float64

# %%
df.iloc[0:2, :]
# Out:
#        Marca A  Marca B  Marca C  Marca D
# Ano 1     36.0     42.0     15.0     19.0
# Ano 2     48.0     19.0     38.0     40.0

# %% [markdown]
# ### Exercício 29

# %%
df['Marca E'] = [70, 77, 81, 103]
df
# Out:
#        Marca A  Marca B  Marca C  Marca D  Marca E
# Ano 1     36.0     42.0     15.0     19.0       70
# Ano 2     48.0     19.0     38.0     40.0       77
# Ano 3     12.0      6.0     43.0     28.0       81
# Ano 4     40.0      7.0      5.0      8.0      103

# %%
df.rename(
    columns = {
        'Marca A': 'A',
        'Marca B': 'B',
        'Marca C': 'C',
        'Marca D': 'D',
        'Marca E': 'E'
    }, inplace = True)

# %%
df.rename(index = lambda coluna:coluna.upper(), inplace = True)

# %%
df
# Out:
#           A     B     C     D    E
# ANO 1  36.0  42.0  15.0  19.0   70
# ANO 2  48.0  19.0  38.0  40.0   77
# ANO 3  12.0   6.0  43.0  28.0   81
# ANO 4  40.0   7.0   5.0   8.0  103

# %%
df.at['ANO 2', 'C'] = 37
df
# Out:
#           A     B     C     D    E
# ANO 1  36.0  42.0  15.0  19.0   70
# ANO 2  48.0  19.0  37.0  40.0   77
# ANO 3  12.0   6.0  43.0  28.0   81
# ANO 4  40.0   7.0   5.0   8.0  103

# %% [markdown]
# ### Exercício 30

# %%
dic = {
    'A': ['a', 'b', 'c'],
    'B': ['f', 'g', 'w'],
    'C': ['z', 'k', 'm']}
df = pd.DataFrame(dic)

# %%
df
# Out:
#    A  B  C
# 0  a  f  z
# 1  b  g  k
# 2  c  w  m

# %%
lista = ['f','b','z']

# %%
df.isin(lista)
# Out:
#        A      B      C
# 0  False   True   True
# 1   True  False  False
# 2  False  False  False

# %% [markdown]
# ### Exercício 31

# %%
data = {
    'A': ['z', 'k' ,'m'],
    'B': ['j', 'n' , 'o'],
    'C': ['o', 'p', 'k'],
    'Z': ['i', 'j' ,'k'],
    'W': ['p', 'k', 'u']
}

df =  pd.DataFrame(data)

# %%
df
# Out:
#    A  B  C  Z  W
# 0  z  j  o  i  p
# 1  k  n  p  j  k
# 2  m  o  k  k  u

# %%
df.drop(labels = ['B', 'Z', 'W'], axis = 1, inplace = True)

# %%
df
# Out:
#    A  C
# 0  z  o
# 1  k  p
# 2  m  k

# %% [markdown]
# ### Exercício 32

# %%
alunos = [
    'Naomi', 'Yumi','Hinata',
    'Hana', 'Akira', 'Yuki',
    'Yudi', 'Sakura', 'Sasuke',
    'Hiroshi', 'Ken', 'Emi']
matematica = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]
quimica = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]
biologia = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]
economia = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]
dados = {
    'Alunos': alunos,
    'Matemática': matematica,
    'Química': quimica,
    'Biologia': biologia,
    'Economia': economia
}

df = pd.DataFrame(data = dados, index = range(1,len(alunos)+1))

# %%
df
# Out:
#      Alunos  Matemática  Química  Biologia  Economia
# 1     Naomi           1        6         8         3
# 2      Yumi           3        5         7         2
# 3    Hinata           1        5         9         7
# 4      Hana           3        8         9         8
# 5     Akira           4        6         7         9
# 6      Yuki           3        6         7         9
# 7      Yudi           1        5         8         5
# 8    Sakura           9        3         7         9
# 9    Sasuke           5        7         7         8
# 10  Hiroshi           9        8         7         6
# 11      Ken           1        6         7         7
# 12      Emi           2        4         9         9

# %%
df.describe().T
# Out:
#             count      mean       std  min   25%  50%   75%  max
# Matemática   12.0  3.500000  2.876235  1.0  1.00  3.0  4.25  9.0
# Química      12.0  5.750000  1.484771  3.0  5.00  6.0  6.25  8.0
# Biologia     12.0  7.666667  0.887625  7.0  7.00  7.0  8.25  9.0
# Economia     12.0  6.833333  2.405801  2.0  5.75  7.5  9.00  9.0

# %%
df['Média Final'] = df.drop(['Alunos'], axis = 1).mean(axis = 1)

# %%
df
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final
# 1     Naomi           1        6         8         3         4.50
# 2      Yumi           3        5         7         2         4.25
# 3    Hinata           1        5         9         7         5.50
# 4      Hana           3        8         9         8         7.00
# 5     Akira           4        6         7         9         6.50
# 6      Yuki           3        6         7         9         6.25
# 7      Yudi           1        5         8         5         4.75
# 8    Sakura           9        3         7         9         7.00
# 9    Sasuke           5        7         7         8         6.75
# 10  Hiroshi           9        8         7         6         7.50
# 11      Ken           1        6         7         7         5.25
# 12      Emi           2        4         9         9         6.00

# %%
def resultado(nota):
    if nota>=7:
        return 'Aprovado'
    else:
        return 'Reprovado'

df['Resultado'] = df['Média Final'].apply(resultado)

# %%
df
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1     Naomi           1        6         8         3         4.50  Reprovado
# 2      Yumi           3        5         7         2         4.25  Reprovado
# 3    Hinata           1        5         9         7         5.50  Reprovado
# 4      Hana           3        8         9         8         7.00   Aprovado
# 5     Akira           4        6         7         9         6.50  Reprovado
# 6      Yuki           3        6         7         9         6.25  Reprovado
# 7      Yudi           1        5         8         5         4.75  Reprovado
# 8    Sakura           9        3         7         9         7.00   Aprovado
# 9    Sasuke           5        7         7         8         6.75  Reprovado
# 10  Hiroshi           9        8         7         6         7.50   Aprovado
# 11      Ken           1        6         7         7         5.25  Reprovado
# 12      Emi           2        4         9         9         6.00  Reprovado

# %% [markdown]
# ### Exercício 33

# %%
df[df['Matemática'] >= 7]
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final Resultado
# 8    Sakura           9        3         7         9          7.0  Aprovado
# 10  Hiroshi           9        8         7         6          7.5  Aprovado

# %%
df[df['Química'] < 5]
# Out:
#     Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 8   Sakura           9        3         7         9          7.0   Aprovado
# 12     Emi           2        4         9         9          6.0  Reprovado

# %%
df[df['Biologia'] == 8]
# Out:
#   Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1  Naomi           1        6         8         3         4.50  Reprovado
# 7   Yudi           1        5         8         5         4.75  Reprovado

# %%
df[df['Economia'] != 9]
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1     Naomi           1        6         8         3         4.50  Reprovado
# 2      Yumi           3        5         7         2         4.25  Reprovado
# 3    Hinata           1        5         9         7         5.50  Reprovado
# 4      Hana           3        8         9         8         7.00   Aprovado
# 7      Yudi           1        5         8         5         4.75  Reprovado
# 9    Sasuke           5        7         7         8         6.75  Reprovado
# 10  Hiroshi           9        8         7         6         7.50   Aprovado
# 11      Ken           1        6         7         7         5.25  Reprovado

# %%
df[df['Média Final'] < 5]
# Out:
#   Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1  Naomi           1        6         8         3         4.50  Reprovado
# 2   Yumi           3        5         7         2         4.25  Reprovado
# 7   Yudi           1        5         8         5         4.75  Reprovado

# %%
df[df['Resultado'] == 'Aprovado']
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final Resultado
# 4      Hana           3        8         9         8          7.0  Aprovado
# 8    Sakura           9        3         7         9          7.0  Aprovado
# 10  Hiroshi           9        8         7         6          7.5  Aprovado

# %% [markdown]
# ### Exercício 34

# %%
df.query('Matemática > = 7')
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final Resultado
# 8    Sakura           9        3         7         9          7.0  Aprovado
# 10  Hiroshi           9        8         7         6          7.5  Aprovado

# %%
df.query('Química < 5')
# Out:
#     Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 8   Sakura           9        3         7         9          7.0   Aprovado
# 12     Emi           2        4         9         9          6.0  Reprovado

# %%
df.query('Biologia == 8')
# Out:
#   Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1  Naomi           1        6         8         3         4.50  Reprovado
# 7   Yudi           1        5         8         5         4.75  Reprovado

# %%
df.query('Economia != 9')
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1     Naomi           1        6         8         3         4.50  Reprovado
# 2      Yumi           3        5         7         2         4.25  Reprovado
# 3    Hinata           1        5         9         7         5.50  Reprovado
# 4      Hana           3        8         9         8         7.00   Aprovado
# 7      Yudi           1        5         8         5         4.75  Reprovado
# 9    Sasuke           5        7         7         8         6.75  Reprovado
# 10  Hiroshi           9        8         7         6         7.50   Aprovado
# 11      Ken           1        6         7         7         5.25  Reprovado

# %%
df.query('`Média Final` < 5')
# Out:
#   Alunos  Matemática  Química  Biologia  Economia  Média Final  Resultado
# 1  Naomi           1        6         8         3         4.50  Reprovado
# 2   Yumi           3        5         7         2         4.25  Reprovado
# 7   Yudi           1        5         8         5         4.75  Reprovado

# %%
df.query("Resultado == 'Aprovado'")
# Out:
#      Alunos  Matemática  Química  Biologia  Economia  Média Final Resultado
# 4      Hana           3        8         9         8          7.0  Aprovado
# 8    Sakura           9        3         7         9          7.0  Aprovado
# 10  Hiroshi           9        8         7         6          7.5  Aprovado

# %% [markdown]
# ### Exercício 35

# %%
dados = {
    'Empresa A': {2018:90, 2019:76, 2020: 109},
    'Empresa B': {2018: 33, 2020: 13},
    'Empresa C': {2018:273, 2019: 33}}

df.columns.name = 'Faturamento'
df.index.name = 'Ano'
df = pd.DataFrame(dados)

# %%
df
# Out:
#       Empresa A  Empresa B  Empresa C
# 2018         90       33.0      273.0
# 2019         76        NaN       33.0
# 2020        109       13.0        NaN

# %% [markdown]
# ### Exercício 36

# %%
df.isna().sum()
# Out:
# Empresa A    0
# Empresa B    1
# Empresa C    1
# dtype: int64

# %% [markdown]
# ### Exercício 37

# %%
df
# Out:
#       Empresa A  Empresa B  Empresa C
# 2018         90       33.0      273.0
# 2019         76        NaN       33.0
# 2020        109       13.0        NaN

# %%
df.fillna(
    {'Empresa B':df['Empresa B'].mean(), 'Empresa C': df['Empresa C'].median()}, 
    inplace = True)
# Out:
#       Empresa A  Empresa B  Empresa C
# 2018         90       33.0      273.0
# 2019         76       23.0       33.0
# 2020        109       13.0      153.0

# %%
print(df.idxmax())
# Out:
# Empresa A    2020
# Empresa B    2018
# Empresa C    2018
# dtype: int64

# %%
print(df.idxmin())
# Out:
# Empresa A    2019
# Empresa B    2020
# Empresa C    2019
# dtype: int64

# %% [markdown]
# ### Exercício 38

# %%
s = pd.Series([15, 31, 41, 47, 39, 10, 33, 13, 31, 33],
              index = pd.date_range(start = '2016', periods = 10, freq = 'Y'))
print('Ano com maior faturamento'.center(50, ' '))
print(s.idxmax().strftime('%Y'))
print('Ano com menor faturamento'.center(50, ' '))
print(s.idxmin().strftime('%Y'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6313, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6180, in pandas._libs.tslibs.offsets._validate_to_offset_alias()
#
# ValueError: 'Y' is no longer supported for offsets. Please use 'YE' instead.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[233], line 2
#       1 s = pd.Series([15, 31, 41, 47, 39, 10, 33, 13, 31, 33],
# ----> 2               index = pd.date_range(start = '2016', periods = 10, freq = 'Y'))
#       3 print('Ano com maior faturamento'.center(50, ' '))
#       4 print(s.idxmax().strftime('%Y'))
#
# File c:\Users\bob\AppData\Local\anaconda3\envs\datascience\Lib\site-packages\pandas\core\indexes\datetimes.py:1442, in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit, **kwargs)
#    1440     freq = "D"
#    1441 if freq is not None:
# -> 1442     freq = to_offset(freq)
#    1444 if start is NaT or end is NaT:
#    1445     # This check needs to come before the `unit = start.unit` line below
#    1446     raise ValueError("Neither `start` nor `end` can be NaT")
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: Y. Failed to parse with error message: ValueError("'Y' is no longer supported for offsets. Please use 'YE' instead.")

# %% [markdown]
# ### Exercício 39

# %%
series = pd.Series(
    np.random.randint(100,150,4), 
    index = ['Year 1', 'Year 2', 'Year 3', 'Year 4'])

# %%
series.drop(index='Year 1',inplace=True)

# %%
series
# Out:
# Year 2    137
# Year 3    134
# Year 4    115
# dtype: int32

# %% [markdown]
# ### Exercício 40

# %%
np.random.seed(77)
data = np.random.randint(1,50,16).reshape((4,4))
df = pd.DataFrame(data, 
                columns = ['A', 'B', 'C', 'D'],
                index = ['i', 'j', 'k', 'w'])

# %%
df
# Out:
#     A   B   C   D
# i  24  32  21  21
# j  44  38  25  32
# k  33  40  45  20
# w  33  37  37  48

# %%
df.drop(['k','j'],inplace=True)

# %%
df.drop(['A','D'], axis=1, inplace=True)

# %%
df
# Out:
#     B   C
# i  32  21
# w  37  37

# %% [markdown]
# ### Exercício 41

# %%
np.random.seed(21)
frequencia = pd.date_range(start = '2020-12-01', periods = 31, freq = 'D')
valores = np.random.normal(30, 0.5, 31)
df = pd.DataFrame(data = valores, index = frequencia, columns = ['Série'])
df
# Out:
#                 Série
# 2020-12-01  29.974018
# 2020-12-02  29.944402
# 2020-12-03  30.520898
# 2020-12-04  29.371630
# 2020-12-05  30.372694
# 2020-12-06  29.144473
# 2020-12-07  29.897068
# 2020-12-08  29.882714
# 2020-12-09  30.564072
# 2020-12-10  29.993687
# 2020-12-11  29.693400
# 2020-12-12  30.686844
# 2020-12-13  30.805496
# 2020-12-14  29.655386
# 2020-12-15  30.345962
# 2020-12-16  29.775942
# 2020-12-17  30.081171
# 2020-12-18  30.128615
# 2020-12-19  29.362272
# 2020-12-20  30.032002
# 2020-12-21  29.469072
# 2020-12-22  29.505316
# 2020-12-23  29.771138
# 2020-12-24  29.007909
# 2020-12-25  29.261779
# 2020-12-26  30.115901
# 2020-12-27  30.322080
# 2020-12-28  30.426061
# 2020-12-29  29.767991
# 2020-12-30  30.348588
# 2020-12-31  30.783941

# %%
df.plot(color = 'k');

# %% [markdown]
# ### Exercício 42

# %%
np.random.seed(21)
meses = pd.date_range(start = '1-1-2021', periods = 12, freq = 'ME')

# %% [markdown]
# ### Exercício 43

# %%
from datetime import datetime

# %%
inicio = datetime(2010,1,1)
fim = datetime(2040,12,31)
anos = pd.date_range(start = inicio , end = fim, freq = 'YE')

# %% [markdown]
# ### Exercício 44

# %%
september2021 = pd.date_range(start = '2021-9-1', periods = 29)

# %%
september2021 = pd.Series(september2021)

# %%
september2021
# Out:
# 0    2021-09-01
# 1    2021-09-02
# 2    2021-09-03
# 3    2021-09-04
# 4    2021-09-05
# 5    2021-09-06
# 6    2021-09-07
# 7    2021-09-08
# 8    2021-09-09
# 9    2021-09-10
# 10   2021-09-11
# 11   2021-09-12
# 12   2021-09-13
# 13   2021-09-14
# 14   2021-09-15
# 15   2021-09-16
# 16   2021-09-17
# 17   2021-09-18
# 18   2021-09-19
# 19   2021-09-20
# 20   2021-09-21
# 21   2021-09-22
# 22   2021-09-23
# 23   2021-09-24
# 24   2021-09-25
# 25   2021-09-26
# 26   2021-09-27
# 27   2021-09-28
# 28   2021-09-29
# dtype: datetime64[us]

# %% [markdown]
# ### Exercício 45

# %%
tri1 = pd.date_range(start = '1-1-2021', periods = 4,freq='3ME')
tri1 = pd.Series(tri1)
tri1
# Out:
# 0   2021-01-31
# 1   2021-04-30
# 2   2021-07-31
# 3   2021-10-31
# dtype: datetime64[us]

# %% [markdown]
# ### Exercício 46

# %%
horas = pd.date_range(start = '2030-12-31', periods = 24, freq ='h')
horas = pd.Series(horas)
horas
# Out:
# 0    2030-12-31 00:00:00
# 1    2030-12-31 01:00:00
# 2    2030-12-31 02:00:00
# 3    2030-12-31 03:00:00
# 4    2030-12-31 04:00:00
# 5    2030-12-31 05:00:00
# 6    2030-12-31 06:00:00
# 7    2030-12-31 07:00:00
# 8    2030-12-31 08:00:00
# 9    2030-12-31 09:00:00
# 10   2030-12-31 10:00:00
# 11   2030-12-31 11:00:00
# 12   2030-12-31 12:00:00
# 13   2030-12-31 13:00:00
# 14   2030-12-31 14:00:00
# 15   2030-12-31 15:00:00
# 16   2030-12-31 16:00:00
# 17   2030-12-31 17:00:00
# 18   2030-12-31 18:00:00
# 19   2030-12-31 19:00:00
# 20   2030-12-31 20:00:00
# 21   2030-12-31 21:00:00
# 22   2030-12-31 22:00:00
# 23   2030-12-31 23:00:00
# dtype: datetime64[us]

# %% [markdown]
# ### Exercício 47

# %%
dias = pd.date_range(start = '2020-9-1', end = '2020-12-31', freq ='D')
dias = pd.Series(dias)
dias
# Out:
# 0     2020-09-01
# 1     2020-09-02
# 2     2020-09-03
# 3     2020-09-04
# 4     2020-09-05
#          ...
# 117   2020-12-27
# 118   2020-12-28
# 119   2020-12-29
# 120   2020-12-30
# 121   2020-12-31
# Length: 122, dtype: datetime64[us]

# %%
meses2 = pd.bdate_range(start = '2020-9-1', end = '2020-12-31')

# %%
meses2
# Out:
# DatetimeIndex(['2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-07', '2020-09-08', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-14', '2020-09-15', '2020-09-16',
#                '2020-09-17', '2020-09-18', '2020-09-21', '2020-09-22',
#                '2020-09-23', '2020-09-24', '2020-09-25', '2020-09-28',
#                '2020-09-29', '2020-09-30', '2020-10-01', '2020-10-02',
#                '2020-10-05', '2020-10-06', '2020-10-07', '2020-10-08',
#                '2020-10-09', '2020-10-12', '2020-10-13', '2020-10-14',
#                '2020-10-15', '2020-10-16', '2020-10-19', '2020-10-20',
#                '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-26',
#                '2020-10-27', '2020-10-28', '2020-10-29', '2020-10-30',
#                '2020-11-02', '2020-11-03', '2020-11-04', '2020-11-05',
#                '2020-11-06', '2020-11-09', '2020-11-10', '2020-11-11',
#                '2020-11-12', '2020-11-13', '2020-11-16', '2020-11-17',
#                '2020-11-18', '2020-11-19', '2020-11-20', '2020-11-23',
#                '2020-11-24', '2020-11-25', '2020-11-26', '2020-11-27',
#                '2020-11-30', '2020-12-01', '2020-12-02', '2020-12-03',
#                '2020-12-04', '2020-12-07', '2020-12-08', '2020-12-09',
#                '2020-12-10', '2020-12-11', '2020-12-14', '2020-12-15',
#                '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31'],
#               dtype='datetime64[us]', freq='B')

# %% [markdown]
# ### Exercício 48

# %%
data = pd.date_range(start = '2021-1-1', end = '2021-6-30', freq = '15D')
data
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-16', '2021-01-31', '2021-02-15',
#                '2021-03-02', '2021-03-17', '2021-04-01', '2021-04-16',
#                '2021-05-01', '2021-05-16', '2021-05-31', '2021-06-15',
#                '2021-06-30'],
#               dtype='datetime64[us]', freq='15D')

# %% [markdown]
# ### Exercício 49

# %%
data = pd.date_range(start = '2021-1-1', end = '2021-12-31', freq = '15D')
df = pd.DataFrame(data, columns = ['Data'])
df
# Out:
#          Data
# 0  2021-01-01
# 1  2021-01-16
# 2  2021-01-31
# 3  2021-02-15
# 4  2021-03-02
# 5  2021-03-17
# 6  2021-04-01
# 7  2021-04-16
# 8  2021-05-01
# 9  2021-05-16
# 10 2021-05-31
# 11 2021-06-15
# 12 2021-06-30
# 13 2021-07-15
# 14 2021-07-30
# 15 2021-08-14
# 16 2021-08-29
# 17 2021-09-13
# 18 2021-09-28
# 19 2021-10-13
# 20 2021-10-28
# 21 2021-11-12
# 22 2021-11-27
# 23 2021-12-12
# 24 2021-12-27

# %%
df['Dia do Ano'] = data.dayofyear
df['Mês do Ano'] = data.month
df
# Out:
#          Data  Dia do Ano  Mês do Ano
# 0  2021-01-01           1           1
# 1  2021-01-16          16           1
# 2  2021-01-31          31           1
# 3  2021-02-15          46           2
# 4  2021-03-02          61           3
# 5  2021-03-17          76           3
# 6  2021-04-01          91           4
# 7  2021-04-16         106           4
# 8  2021-05-01         121           5
# 9  2021-05-16         136           5
# 10 2021-05-31         151           5
# 11 2021-06-15         166           6
# 12 2021-06-30         181           6
# 13 2021-07-15         196           7
# 14 2021-07-30         211           7
# 15 2021-08-14         226           8
# 16 2021-08-29         241           8
# 17 2021-09-13         256           9
# 18 2021-09-28         271           9
# 19 2021-10-13         286          10
# 20 2021-10-28         301          10
# 21 2021-11-12         316          11
# 22 2021-11-27         331          11
# 23 2021-12-12         346          12
# 24 2021-12-27         361          12

# %% [markdown]
# ### Exercício 50

# %%
n = 1096 #total de observações
dados = {
    'A': np.random.randint(low = 1, high = 1500, size = n),
    'B': np.random.normal(loc = 10, scale = 2, size = n),
    'C': np.random.uniform(low = 0, high = 1, size = n),
    'D': np.random.lognormal(mean = 4, sigma = 5, size = n),
    'E': np.random.standard_normal(size = n)}

df = pd.DataFrame(dados,index= pd.date_range(start='2018-01-01',end='2020-12-31'))

# %%
n = dias.shape[0]

# %%
df
# Out:
#                A          B         C             D         E
# 2018-01-01   237   8.579289  0.245679    250.316357 -1.410176
# 2018-01-02   406  14.420358  0.831051    156.506832 -0.139214
# 2018-01-03  1169   9.858293  0.625437      0.135085 -0.662517
# 2018-01-04  1017   9.680411  0.619986  21448.491935 -0.043872
# 2018-01-05   306  14.536910  0.291849  10841.918943 -0.618773
# ...          ...        ...       ...           ...       ...
# 2020-12-27    80  12.023046  0.914516    572.188864  0.046143
# 2020-12-28   801  11.028774  0.369603    153.610967  2.027455
# 2020-12-29   963  10.632625  0.615132    988.474068  0.707362
# 2020-12-30   769  14.427223  0.287126     86.653152 -1.662773
# 2020-12-31  1319   4.103935  0.655425      1.949836 -0.223787
#
# [1096 rows x 5 columns]

# %% [markdown]
# ### Exercício 51

# %%
df
# Out:
#                A          B         C             D         E
# 2018-01-01   237   8.579289  0.245679    250.316357 -1.410176
# 2018-01-02   406  14.420358  0.831051    156.506832 -0.139214
# 2018-01-03  1169   9.858293  0.625437      0.135085 -0.662517
# 2018-01-04  1017   9.680411  0.619986  21448.491935 -0.043872
# 2018-01-05   306  14.536910  0.291849  10841.918943 -0.618773
# ...          ...        ...       ...           ...       ...
# 2020-12-27    80  12.023046  0.914516    572.188864  0.046143
# 2020-12-28   801  11.028774  0.369603    153.610967  2.027455
# 2020-12-29   963  10.632625  0.615132    988.474068  0.707362
# 2020-12-30   769  14.427223  0.287126     86.653152 -1.662773
# 2020-12-31  1319   4.103935  0.655425      1.949836 -0.223787
#
# [1096 rows x 5 columns]

# %%
df.describe().T
# Out:
#     count           mean           std       min         25%         50%  \
# A  1096.0     751.427920  4.323624e+02  3.000000  377.500000  741.500000
# B  1096.0       9.998077  1.994549e+00  3.516198    8.660421    9.962264
# C  1096.0       0.507623  2.900472e-01  0.001664    0.262965    0.511010
# D  1096.0  299033.404820  3.771521e+06  0.000022    2.059003   43.925394
# E  1096.0       0.021172  1.020397e+00 -3.508053   -0.672982    0.003648
#
#            75%           max
# A  1120.250000  1.499000e+03
# B    11.344934  1.784518e+01
# C     0.756537  9.984920e-01
# D  1279.430329  9.644664e+07
# E     0.730286  2.643145e+00

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1096 entries, 2018-01-01 to 2020-12-31
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1096 non-null   int32
#  1   B       1096 non-null   float64
#  2   C       1096 non-null   float64
#  3   D       1096 non-null   float64
#  4   E       1096 non-null   float64
# dtypes: float64(4), int32(1)
# memory usage: 47.1 KB

# %%
df.corr()
# Out:
#           A         B         C         D         E
# A  1.000000 -0.021156 -0.006395 -0.022004 -0.012498
# B -0.021156  1.000000 -0.006510 -0.001007  0.046723
# C -0.006395 -0.006510  1.000000 -0.019573  0.052882
# D -0.022004 -0.001007 -0.019573  1.000000  0.032553
# E -0.012498  0.046723  0.052882  0.032553  1.000000

# %%
df.cov()
# Out:
#               A            B             C             D              E
# A  1.869372e+05   -18.244587     -0.801906 -3.588180e+07      -5.513773
# B -1.824459e+01     3.978224     -0.003766 -7.573993e+03       0.095093
# C -8.019062e-01    -0.003766      0.084127 -2.141087e+04       0.015651
# D -3.588180e+07 -7573.992796 -21410.866858  1.422437e+13  125277.492577
# E -5.513773e+00     0.095093      0.015651  1.252775e+05       1.041211

# %% [markdown]
# ### Exercício 52

# %%
np.random.seed(99)
index = [chr(65+i) for i in range(10)]
series = pd.Series(np.random.normal(loc = 10, scale = 0.5, size = 10), index, name = 'Data')
series
# Out:
# A     9.928821
# B    11.028611
# C    10.141631
# D    10.664906
# E     9.922689
# F     9.965485
# G    10.377590
# H    10.412823
# I     9.943465
# J     8.816081
# Name: Data, dtype: float64

# %% [markdown]
# ### Exercício 53

# %%
dados = {
    'W': np.random.randint(1,10,10),
    'Z': np.random.uniform(0,10,10),
    'K': np.linspace(1,50,10),
    'J': np.arange(10),
    'L': np.random.beta(1,10,10),
    'M': np.random.exponential(1,10),
    'Y': np.random.randint(-50,-1,10)
}
index = pd.date_range(start='2020-12-01', end='2020-12-10')
df = pd.DataFrame(dados,index = index)

# %%
df
# Out:
#             W         Z          K  J         L         M   Y
# 2020-12-01  3  9.990471   1.000000  0  0.278352  1.339713 -25
# 2020-12-02  3  9.660746   6.444444  1  0.045270  0.085680 -48
# 2020-12-03  6  6.016911  11.888889  2  0.009785  1.345626 -46
# 2020-12-04  2  7.682832  17.333333  3  0.023539  0.906700 -46
# 2020-12-05  6  2.067390  22.777778  4  0.088351  1.432500  -5
# 2020-12-06  7  8.862631  28.222222  5  0.066343  0.018937 -31
# 2020-12-07  6  4.231032  33.666667  6  0.107005  0.368914 -47
# 2020-12-08  5  2.167873  39.111111  7  0.004296  1.431724 -38
# 2020-12-09  4  8.706170  44.555556  8  0.017631  0.876104  -6
# 2020-12-10  2  1.192674  50.000000  9  0.049738  1.860226 -39

# %%
df.columns
# Out:
# Index(['W', 'Z', 'K', 'J', 'L', 'M', 'Y'], dtype='str')

# %%
df = pd.DataFrame(dados, 
                  index = pd.date_range(start = '2020-12-1', periods = 10))
 
for coluna in df:
    print(coluna)
# Out:
# W
# Z
# K
# J
# L
# M
# Y

# %% [markdown]
# ### Exercício 54

# %%
dados = {
    'A': np.arange(3),
    'B': [n**2 for n in range(1,4)],
    'C': [n for n in range(1,7) if n%2==0]}
 
df = pd.DataFrame(dados, index = pd.date_range(start = '2020-12-1', periods = 3, freq = 'ME'))
df
# Out:
#             A  B  C
# 2020-12-31  0  1  2
# 2021-01-31  1  4  4
# 2021-02-28  2  9  6

# %%
for coluna,valores in df.items():
    print(coluna)
    print(f'\tSoma dos valores: {valores.sum()}')
    print(f'\tValor mínimo: {valores.min()}')
    print(f'\tValor máximo: {valores.max()}')
    print(f'\tMédia dos valores: {valores.mean().round(2)}')
    print(f'\tDesvio padrão: {valores.std().round(2)}')
    print()
# Out:
# A
# 	Soma dos valores: 3
# 	Valor mínimo: 0
# 	Valor máximo: 2
# 	Média dos valores: 1.0
# 	Desvio padrão: 1.0
#
# B
# 	Soma dos valores: 14
# 	Valor mínimo: 1
# 	Valor máximo: 9
# 	Média dos valores: 4.67
# 	Desvio padrão: 4.04
#
# C
# 	Soma dos valores: 12
# 	Valor mínimo: 2
# 	Valor máximo: 6
# 	Média dos valores: 4.0
# 	Desvio padrão: 2.0

# %% [markdown]
# ### Exercício 55

# %%
dias = pd.date_range(start = '2021-1-1', periods = 10)
df = pd.DataFrame(np.arange(1, 31).reshape(10, 3), 
                  columns = list('ABC'),
                  index = dias
                 )
 
for linha_indice, linha in df.iterrows():
    print(linha_indice.strftime('%d/%m/%Y'))
    print('Soma: '+str(linha.sum()))
    print()
# Out:
# 01/01/2021
# Soma: 6
#
# 02/01/2021
# Soma: 15
#
# 03/01/2021
# Soma: 24
#
# 04/01/2021
# Soma: 33
#
# 05/01/2021
# Soma: 42
#
# 06/01/2021
# Soma: 51
#
# 07/01/2021
# Soma: 60
#
# 08/01/2021
# Soma: 69
#
# 09/01/2021
# Soma: 78
#
# 10/01/2021
# Soma: 87

# %% [markdown]
# ### Exercício 56

# %%
dias = pd.date_range(start = '2021-1-1', periods = 10)
df = pd.DataFrame(
    data = np.arange(1, 31).reshape(10, 3), 
    columns = list('ABC'),
    index = dias)

# %%
df
# Out:
#              A   B   C
# 2021-01-01   1   2   3
# 2021-01-02   4   5   6
# 2021-01-03   7   8   9
# 2021-01-04  10  11  12
# 2021-01-05  13  14  15
# 2021-01-06  16  17  18
# 2021-01-07  19  20  21
# 2021-01-08  22  23  24
# 2021-01-09  25  26  27
# 2021-01-10  28  29  30

# %%
for linha in df.itertuples():
    print(linha)
# Out:
# Pandas(Index=Timestamp('2021-01-01 00:00:00'), A=1, B=2, C=3)
# Pandas(Index=Timestamp('2021-01-02 00:00:00'), A=4, B=5, C=6)
# Pandas(Index=Timestamp('2021-01-03 00:00:00'), A=7, B=8, C=9)
# Pandas(Index=Timestamp('2021-01-04 00:00:00'), A=10, B=11, C=12)
# Pandas(Index=Timestamp('2021-01-05 00:00:00'), A=13, B=14, C=15)
# Pandas(Index=Timestamp('2021-01-06 00:00:00'), A=16, B=17, C=18)
# Pandas(Index=Timestamp('2021-01-07 00:00:00'), A=19, B=20, C=21)
# Pandas(Index=Timestamp('2021-01-08 00:00:00'), A=22, B=23, C=24)
# Pandas(Index=Timestamp('2021-01-09 00:00:00'), A=25, B=26, C=27)
# Pandas(Index=Timestamp('2021-01-10 00:00:00'), A=28, B=29, C=30)

# %% [markdown]
# ### Exercício 57

# %%
dias = pd.date_range(start = '2020-1-1', periods = 10).to_numpy().copy()
np.random.shuffle(dias)

df = pd.DataFrame(
    data = np.random.normal(10, 3.5, (10, 3)),
    columns = list('ABC'),
    index = dias
)
df
# Out:
#                     A          B          C
# 2020-01-03  10.607407   5.720756   9.979912
# 2020-01-05  11.172301  12.604317  12.889380
# 2020-01-10   6.120838  11.310757   6.941034
# 2020-01-09   8.491162  15.452711  14.832571
# 2020-01-04   6.313298  10.040109  16.491400
# 2020-01-06   3.593144   9.832742  14.665935
# 2020-01-01  12.501567   8.748266   9.436715
# 2020-01-02  10.861921  13.213348  11.386441
# 2020-01-07  13.868597   6.914725   7.429333
# 2020-01-08   5.883497  11.605701  10.943473

# %%
df.sort_index()
# Out:
#                     A          B          C
# 2020-01-01  12.501567   8.748266   9.436715
# 2020-01-02  10.861921  13.213348  11.386441
# 2020-01-03  10.607407   5.720756   9.979912
# 2020-01-04   6.313298  10.040109  16.491400
# 2020-01-05  11.172301  12.604317  12.889380
# 2020-01-06   3.593144   9.832742  14.665935
# 2020-01-07  13.868597   6.914725   7.429333
# 2020-01-08   5.883497  11.605701  10.943473
# 2020-01-09   8.491162  15.452711  14.832571
# 2020-01-10   6.120838  11.310757   6.941034

# %% [markdown]
# ### Exercício 58

# %%
dados = {
    'Pontos':[56, 74, 63, 63, 72, 50, 63, 44, 80 ],
    'Rank':[8, 3, 6, 2, 1, 13, 5, 13, 1],
    'Ano':[2019, 2019, 2019, 2017, 2017, 2017, 2018, 2018, 2018],
    'Time':['Corinthians', 'Palmeiras', 'São Paulo', 
            'Palmeiras', 'Corinthians', 'São Paulo',
            'São Paulo', 'Corinthians', 'Palmeiras']}
df = pd.DataFrame(dados)
df
# Out:
#    Pontos  Rank   Ano         Time
# 0      56     8  2019  Corinthians
# 1      74     3  2019    Palmeiras
# 2      63     6  2019    São Paulo
# 3      63     2  2017    Palmeiras
# 4      72     1  2017  Corinthians
# 5      50    13  2017    São Paulo
# 6      63     5  2018    São Paulo
# 7      44    13  2018  Corinthians
# 8      80     1  2018    Palmeiras

# %%
df.groupby('Time')['Pontos'].mean().round(2)
# Out:
# Time
# Corinthians    57.33
# Palmeiras      72.33
# São Paulo      58.67
# Name: Pontos, dtype: float64

# %%
df.groupby('Ano')[['Pontos']].agg([np.min,np.max])
# Out:
#      Pontos
#         min max
# Ano
# 2017     50  72
# 2018     44  80
# 2019     56  74

# %%
df.groupby('Ano')['Pontos'].mean().round(2)
# Out:
# Ano
# 2017    61.67
# 2018    62.33
# 2019    64.33
# Name: Pontos, dtype: float64

# %%
df[df['Rank'] <= 5].groupby('Ano')['Time'].count()
# Out:
# Ano
# 2017    2
# 2018    2
# 2019    1
# Name: Time, dtype: int64

# %%
df.groupby('Time')['Pontos'].agg([np.mean, np.std, np.var, np.median])
# Out:
#                   mean        std         var  median
# Time
# Corinthians  57.333333  11.469767  131.555556    56.0
# Palmeiras    72.333333   7.039571   49.555556    74.0
# São Paulo    58.666667   6.128259   37.555556    63.0

# %% [markdown]
# ### Exercício 59

# %%
data1 = {
    'A': ['A0','A1','A2','A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    }
 
data2 = {
    'A':['A4', 'A5', 'A6', 'A7'],
    'B':['B4', 'B5', 'B6', 'B7'],
    'C':['C4', 'C5', 'C6', 'C7'],
    }
 
index = [1, 2, 3, 4]

# %%
df1 = pd.DataFrame(data1, index)
df2 = pd.DataFrame(data2, index)

# %%
data1 = pd.concat([df1, df2], keys = ['Group A', 'Group B'])

# %%
data1
# Out:
#             A   B   C
# Group A 1  A0  B0  C0
#         2  A1  B1  C1
#         3  A2  B2  C2
#         4  A3  B3  C3
# Group B 1  A4  B4  C4
#         2  A5  B5  C5
#         3  A6  B6  C6
#         4  A7  B7  C7

# %%
data2 = pd.concat([df1, df2],ignore_index = True)

# %%
data2
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5
# 6  A6  B6  C6
# 7  A7  B7  C7

# %%
data3 = pd.concat([df1, df2], axis = 1)
data3
# Out:
#     A   B   C   A   B   C
# 1  A0  B0  C0  A4  B4  C4
# 2  A1  B1  C1  A5  B5  C5
# 3  A2  B2  C2  A6  B6  C6
# 4  A3  B3  C3  A7  B7  C7

# %%
data4 = pd.concat([df1, df2], axis = 1, keys = ['Group A', 'Group B'])
data4
# Out:
#   Group A         Group B
#         A   B   C       A   B   C
# 1      A0  B0  C0      A4  B4  C4
# 2      A1  B1  C1      A5  B5  C5
# 3      A2  B2  C2      A6  B6  C6
# 4      A3  B3  C3      A7  B7  C7

# %% [markdown]
# ### Exercício 60

# %%
index = [1, 2, 3]
df1 = pd.DataFrame({
    'A': ['A0','A1','A2',],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2'],
    }, index = index)
 
df2 = pd.DataFrame({
    'A':['A3', 'A4', 'A5'],
    'B':['B3', 'B4', 'B5'],
    'C':['C3', 'C4', 'C5'],
    }, index = index)
 
df3 = pd.DataFrame({
    'A': ['A6', 'A7', 'A8'],
    'B': ['B6', 'B7', 'B8'],
    'C': ['C6', 'C7', 'C8']
    }, index = index)

# %%
df1 = pd.DataFrame(df1, index)
df2 = pd.DataFrame(df2, index)
df3 = pd.DataFrame(df3, index)

# %%
df1
# Out:
#     A   B   C
# 1  A0  B0  C0
# 2  A1  B1  C1
# 3  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 1  A3  B3  C3
# 2  A4  B4  C4
# 3  A5  B5  C5

# %%
data3 = pd.concat([df1, df2],ignore_index=True)
data3
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
data4 = pd.concat([df1, df2,df3])
data4
# Out:
#     A   B   C
# 1  A0  B0  C0
# 2  A1  B1  C1
# 3  A2  B2  C2
# 1  A3  B3  C3
# 2  A4  B4  C4
# 3  A5  B5  C5
# 1  A6  B6  C6
# 2  A7  B7  C7
# 3  A8  B8  C8

# %%
data1 = pd.concat([df1, df2], ignore_index=True)
data2 = pd.concat([df1, df2, df3])

# %%
data1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
data2
# Out:
#     A   B   C
# 1  A0  B0  C0
# 2  A1  B1  C1
# 3  A2  B2  C2
# 1  A3  B3  C3
# 2  A4  B4  C4
# 3  A5  B5  C5
# 1  A6  B6  C6
# 2  A7  B7  C7
# 3  A8  B8  C8

# %% [markdown]
# ### Exercício 61

# %%
data = {
    'A': [10, np.nan, 35, 47, 17, 13],
    'B': ['A', np.nan, 'B', 'A', 'A', np.nan],
    'C': [139, np.nan, np.nan, 199, 111, 140]}

df = pd.DataFrame(data,index=pd.date_range('2020-01-01','2020-01-06'))

# %%
df
# Out:
#                A    B      C
# 2020-01-01  10.0    A  139.0
# 2020-01-02   NaN  NaN    NaN
# 2020-01-03  35.0    B    NaN
# 2020-01-04  47.0    A  199.0
# 2020-01-05  17.0    A  111.0
# 2020-01-06  13.0  NaN  140.0

# %%
df.isna()
# Out:
#                 A      B      C
# 2020-01-01  False  False  False
# 2020-01-02   True   True   True
# 2020-01-03  False  False   True
# 2020-01-04  False  False  False
# 2020-01-05  False  False  False
# 2020-01-06  False   True  False

# %%
df = df.dropna(axis = 0)
df
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0

# %% [markdown]
# ### Exercício 62

# %%
def mostrar_nan(data_frame):    
    if isinstance(data_frame, pd.core.frame.DataFrame):
        return ((data_frame.isna().sum()/data_frame.shape[0]).round(3))*100
    else:
        return None

# %%
index = pd.date_range(start = '2020-1-1', end = '2020-1-6', freq = 'D')
data = {
    'A':[10, np.nan, 35, 47, 17, 13],
    'B':['A', np.nan, 'B', 'A', 'A', np.nan],
    'C':[139, np.nan, np.nan, 199, 111, 140]}

df = pd.DataFrame(data, index = index)

# %%
df
# Out:
#                A    B      C
# 2020-01-01  10.0    A  139.0
# 2020-01-02   NaN  NaN    NaN
# 2020-01-03  35.0    B    NaN
# 2020-01-04  47.0    A  199.0
# 2020-01-05  17.0    A  111.0
# 2020-01-06  13.0  NaN  140.0

# %%
mostrar_nan(df)
# Out:
# A    16.7
# B    33.3
# C    33.3
# dtype: float64

# %% [markdown]
# ### Exercício 63

# %%
df = df.fillna(value=0)

# %%
df
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-02   0.0  0    0.0
# 2020-01-03  35.0  B    0.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0
# 2020-01-06  13.0  0  140.0

# %% [markdown]
# ### Exercício 64

# %%
print(df.columns) 

fill_missing = {
    'A': df['A'].mean(),
    'B': df['B'].mode()[0],
    'C': 'A' 
}

df.fillna(value=fill_missing, inplace=True)
# Out:
# Index(['A', 'B', 'C'], dtype='str')
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-02   0.0  0    0.0
# 2020-01-03  35.0  B    0.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0
# 2020-01-06  13.0  0  140.0

# %%
df
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-02   0.0  0    0.0
# 2020-01-03  35.0  B    0.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0
# 2020-01-06  13.0  0  140.0

# %% [markdown]
# ### Exercício 65

# %%
data = {
    'Brand': ['A', 'A', 'D', 'W', 'K'],
    'ID': [1, 1, 3, 5, 7],
    'Rating':[3.5, 3.5, 4, 8.2, 1]}
 
df = pd.DataFrame(data)

# %%
df
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 1     A   1     3.5
# 2     D   3     4.0
# 3     W   5     8.2
# 4     K   7     1.0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W   5     8.2
# 4     K   7     1.0

# %%
df.at[3, 'ID'] = 11

# %%
df
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2
# 4     K   7     1.0

# %%
df.sort_values(by = 'Rating', inplace = True)

# %%
df.set_index('ID', inplace = True)

# %%
dicionario_dados = df.to_dict()

# %%
dicionario_dados
# Out:
# {'Brand': {7: 'K', 1: 'A', 3: 'D', 11: 'W'},
#  'Rating': {7: 1.0, 1: 3.5, 3: 4.0, 11: 8.2}}

# %% [markdown]
# ### Exercícios 66 - 70

# %%
data = pd.read_csv('insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 73.3 KB

# %%
data.dtypes
# Out:
# age           int64
# sex             str
# bmi         float64
# children      int64
# smoker          str
# region          str
# charges     float64
# dtype: object

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
data['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
for col in data:
    if col == 'bmi':
        continue
    else:
        print(col.upper())
        print(data[col].unique())
        print()
# Out:
# AGE
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
# SEX
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str
#
# CHILDREN
# [0 1 3 2 5 4]
#
# SMOKER
# <StringArray>
# ['yes', 'no']
# Length: 2, dtype: str
#
# REGION
# <StringArray>
# ['southwest', 'southeast', 'northwest', 'northeast']
# Length: 4, dtype: str
#
# CHARGES
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %%
data['age'].value_counts().sort_index()
# Out:
# age
# 18    69
# 19    68
# 20    29
# 21    28
# 22    28
# 23    28
# 24    28
# 25    28
# 26    28
# 27    28
# 28    28
# 29    27
# 30    27
# 31    27
# 32    26
# 33    26
# 34    26
# 35    25
# 36    25
# 37    25
# 38    25
# 39    25
# 40    27
# 41    27
# 42    27
# 43    27
# 44    27
# 45    29
# 46    29
# 47    29
# 48    29
# 49    28
# 50    29
# 51    29
# 52    29
# 53    28
# 54    28
# 55    26
# 56    26
# 57    26
# 58    25
# 59    25
# 60    23
# 61    23
# 62    23
# 63    23
# 64    22
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
data.select_dtypes(include = 'object')
# Out:
# C:\Users\bob\AppData\Local\Temp\ipykernel_13016\379475500.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include = 'object')
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
data.select_dtypes(include = ['float', 'int'])
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
lista = (data.select_dtypes(include = ['float', 'int'])).columns.to_list()

# %%
lista
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
lista2 = (data.select_dtypes(include = ['object'])).columns.to_list()
# Out:
# C:\Users\bob\AppData\Local\Temp\ipykernel_13016\2160181844.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   lista2 = (data.select_dtypes(include = ['object'])).columns.to_list()

# %%
lista2
# Out:
# ['sex', 'smoker', 'region']

# %%
for col in lista2:
    data[col] = data[col].astype('category')

# %%
data.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
data[lista2].describe().T
# Out:
#        count unique        top  freq
# sex     1337      2       male   675
# smoker  1337      2         no  1063
# region  1337      4  southeast   364

# %%
data[lista].describe().T
# Out:
#            count          mean           std        min       25%        50%  \
# age       1337.0     39.222139     14.044333    18.0000    27.000    39.0000
# bmi       1337.0     30.663452      6.100468    15.9600    26.290    30.4000
# children  1337.0      1.095737      1.205571     0.0000     0.000     1.0000
# charges   1337.0  13279.121487  12110.359656  1121.8739  4746.344  9386.1613
#
#                   75%          max
# age          51.00000     64.00000
# bmi          34.70000     53.13000
# children      2.00000      5.00000
# charges   16657.71745  63770.42801

# %%
data['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
data.query('age >= 62')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 26     63  female  23.085         0     no  northeast  14451.83515
# 33     63    male  28.310         0     no  northwest  13770.09790
# 36     62  female  32.965         3     no  northwest  15612.19335
# 62     64    male  24.700         1     no  northwest  30166.61817
# ...   ...     ...     ...       ...    ...        ...          ...
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1322   62    male  38.830         0     no  southeast  12981.34570
#
# [68 rows x 7 columns]

# %%
data.query('age == 18')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 46     18  female  38.665         2     no  northeast   3393.35635
# 50     18  female  35.625         0     no  northeast   2211.13075
# ...   ...     ...     ...       ...    ...        ...          ...
# 1296   18    male  26.125         0     no  northeast   1708.92575
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
#
# [69 rows x 7 columns]

# %%
data.query("region == 'southwest'").shape[0]
# Out:
# 325

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
data.sort_values(by='age',ascending=True)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 1     18    male  33.770         1     no  southeast   1725.55230
# 22    18    male  34.100         0     no  southeast   1137.01100
# 50    18  female  35.625         0     no  northeast   2211.13075
# 866   18    male  37.290         0     no  southeast   1141.44510
# 369   18    male  30.400         3     no  northeast   3481.86800
# ..   ...     ...     ...       ...    ...        ...          ...
# 801   64  female  35.970         0     no  southeast  14313.84630
# 768   64  female  39.700         0     no  southwest  14319.03100
# 752   64    male  37.905         0     no  northwest  14210.53595
# 825   64  female  31.825         2     no  northeast  16069.08475
# 94    64  female  31.300         2    yes  southwest  47291.05500
#
# [1337 rows x 7 columns]

# %%
data['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

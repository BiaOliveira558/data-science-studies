# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Exercício 1

# %%
dados = {
    'Abacate':{
        2017: 212873,
        2018: 236177,
        2019: 242932
    },
    'Açaí':{
        2017:1335040,
        2018:1301472,
        2019:1398328
    },
    'Banana':{
        2017:6584967,
        2018:6723590,
        2019:6812708
    },
    'Cacau':{
        2017:235809,
        2018:239318,
        2019:259425
    },
    'Laranja':{
        2017:17492882,
        2018:16841549,
        2019:17073593
    },
    'Maçã':{
        2017:1307642,
        2018:1203007,
        2019:1222970
    },
    'Mamão':{
        2017:1058487,
        2018:1065421,
        2019:1161808
    },
    'Manga':{
        2017:1089882,
        2018:1320458,
        2019:1414338
    },

}

df = pd.DataFrame(dados)

# %%
df
# Out:
#       Abacate     Açaí   Banana   Cacau   Laranja     Maçã    Mamão    Manga
# 2017   212873  1335040  6584967  235809  17492882  1307642  1058487  1089882
# 2018   236177  1301472  6723590  239318  16841549  1203007  1065421  1320458
# 2019   242932  1398328  6812708  259425  17073593  1222970  1161808  1414338

# %%
print(df.sum(axis = 1))
# Out:
# 2017    29317582
# 2018    28930992
# 2019    29586102
# dtype: int64

# %%
print(df.sum(axis = 0))
# Out:
# Abacate      691982
# Açaí        4034840
# Banana     20121265
# Cacau        734552
# Laranja    51408024
# Maçã        3733619
# Mamão       3285716
# Manga       3824678
# dtype: int64

# %%
print(df.describe())
# Out:
#              Abacate          Açaí        Banana          Cacau       Laranja  \
# count       3.000000  3.000000e+00  3.000000e+00       3.000000  3.000000e+00
# mean   230660.666667  1.344947e+06  6.707088e+06  244850.666667  1.713601e+07
# std     15770.488906  4.918209e+04  1.147638e+05   12743.102618  3.301218e+05
# min    212873.000000  1.301472e+06  6.584967e+06  235809.000000  1.684155e+07
# 25%    224525.000000  1.318256e+06  6.654278e+06  237563.500000  1.695757e+07
# 50%    236177.000000  1.335040e+06  6.723590e+06  239318.000000  1.707359e+07
# 75%    239554.500000  1.366684e+06  6.768149e+06  249371.500000  1.728324e+07
# max    242932.000000  1.398328e+06  6.812708e+06  259425.000000  1.749288e+07
#
#                Maçã         Mamão         Manga
# count  3.000000e+00  3.000000e+00  3.000000e+00
# mean   1.244540e+06  1.095239e+06  1.274893e+06
# std    5.555231e+04  5.775489e+04  1.669583e+05
# min    1.203007e+06  1.058487e+06  1.089882e+06
# ...

# %%
df.to_csv('datasets/dados_prod.csv', index = False)

# %% [markdown]
# ### Exercício 2

# %%
print(df.mean(axis = 1))
# Out:
# 2017    3664697.75
# 2018    3616374.00
# 2019    3698262.75
# dtype: float64

# %%
print(df.mean(axis = 0))
# Out:
# Abacate    2.306607e+05
# Açaí       1.344947e+06
# Banana     6.707088e+06
# Cacau      2.448507e+05
# Laranja    1.713601e+07
# Maçã       1.244540e+06
# Mamão      1.095239e+06
# Manga      1.274893e+06
# dtype: float64

# %%
print(df.std(axis = 1))
# Out:
# 2017    5.950079e+06
# 2018    5.736500e+06
# 2019    5.799394e+06
# dtype: float64

# %%
print(df.std(axis = 0))
# Out:
# Abacate     15770.488906
# Açaí        49182.087363
# Banana     114763.755264
# Cacau       12743.102618
# Laranja    330121.785696
# Maçã        55552.305950
# Mamão       57754.888921
# Manga      166958.299241
# dtype: float64

# %%
print(df.var(axis = 1))
# Out:
# 2017    3.540344e+13
# 2018    3.290743e+13
# 2019    3.363298e+13
# dtype: float64

# %%
print(df.var(axis = 0))
# Out:
# Abacate    2.487083e+08
# Açaí       2.418878e+09
# Banana     1.317072e+10
# Cacau      1.623867e+08
# Laranja    1.089804e+11
# Maçã       3.086059e+09
# Mamão      3.335627e+09
# Manga      2.787507e+10
# dtype: float64

# %% [markdown]
# ### Exercício 3

# %%
vendas = [10, 38, 47, 9, 11, 9, 21, 49, 17, 29]
index = pd.date_range(start = '12/1/2020', periods = 10)
df = pd.DataFrame(vendas, index= index, columns = ['Vendas Diárias'])

# %%
df.mean()
# Out:
# Vendas Diárias    24.0
# dtype: float64

# %%
df.std()
# Out:
# Vendas Diárias    15.804359
# dtype: float64

# %%
df.var()
# Out:
# Vendas Diárias    249.777778
# dtype: float64

# %%
df.mode()
# Out:
#    Vendas Diárias
# 0               9

# %%
df.sum()
# Out:
# Vendas Diárias    240
# dtype: int64

# %%
df.idxmax()
# Out:
# Vendas Diárias   2020-12-08
# dtype: datetime64[us]

# %%
df.idxmin()
# Out:
# Vendas Diárias   2020-12-04
# dtype: datetime64[us]

# %%
data_valor_max = df.idxmax()  #data com a maior venda
data_valor_min = df.idxmin() #data com a menor venda
 
print('Estatísticas descritivas das vendas diárias'.center(100, ' '))
print(f'\tMédia das vendas diárias: {df.mean()}')
print(f'\tDesvio padrão das vendas: {df.std().round(2)}')
print(f'\tVariância das vendas: {df.var().round(2)}')
print(f'\tValor modal: {df.mode().iloc}')
print(f'\tQuantidade vendida no período: {df.sum()}')
print(f'\tValor máximo: {df.max()}')
print(f"\t\tDia: {data_valor_max.strftime('%d/%m/%Y')}")
print(f'\tValor mínimo: {df.min()}')
print(f"\t\tDia: {data_valor_min.strftime('%d/%m/%Y')}")
# Out:
#                             Estatísticas descritivas das vendas diárias
# 	Média das vendas diárias: Vendas Diárias    24.0
# dtype: float64
# 	Desvio padrão das vendas: Vendas Diárias    15.8
# dtype: float64
# 	Variância das vendas: Vendas Diárias    249.78
# dtype: float64
# 	Valor modal: <pandas.core.indexing._iLocIndexer object at 0x000001BD51FC6710>
# 	Quantidade vendida no período: Vendas Diárias    240
# dtype: int64
# 	Valor máximo: Vendas Diárias    49
# dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6540\2315787222.py in ?()
#       7 print(f'\tVariância das vendas: {df.var().round(2)}')
#       8 print(f'\tValor modal: {df.mode().iloc}')
#       9 print(f'\tQuantidade vendida no período: {df.sum()}')
#      10 print(f'\tValor máximo: {df.max()}')
# ---> 11 print(f"\t\tDia: {data_valor_max.strftime('%d/%m/%Y')}")
# ...

# %% [markdown]
# ### Exercício 4

# %%
df = pd.read_csv('datasets/CardioGoodFitness2.csv')

# %%
df.head(n = 3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
df.tail(2)
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 178    120
# 179    180

# %%
df.shape
# Out:
# (180, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    str
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    str
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    str
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), str(3)
# memory usage: 12.8 KB

# %%
df.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %%
df.dtypes
# Out:
# Product            str
# Age              int64
# Gender             str
# Education        int64
# MaritalStatus      str
# Usage            int64
# Fitness          int64
# Income           int64
# Miles            int64
# dtype: object

# %%
df['Income'] = df['Income'].astype(float)

# %% [markdown]
# ### Exercício 5

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# ### Exercício 6

# %%
df['Age'].value_counts().sort_index()
# Out:
# Age
# 18     1
# 19     4
# 20     5
# 21     7
# 22     7
# 23    18
# 24    12
# 25    25
# 26    12
# 27     7
# 28     9
# 29     6
# 30     7
# 31     6
# 32     4
# 33     8
# 34     6
# 35     8
# 36     1
# 37     2
# 38     7
# 39     1
# 40     5
# 41     1
# 42     1
# 43     1
# 44     1
# 45     2
# 46     1
# 47     2
# 48     2
# 50     1
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(28.788888888888888)

# %%
print(df['Gender'].unique())
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
female = df[df['Gender'] == 'Female'].copy()
male = df[df['Gender'] == 'Male'].copy()

# %%
female['Age'].describe()
# Out:
# count    76.000000
# mean     28.565789
# std       6.342104
# min      19.000000
# 25%      24.000000
# 50%      26.500000
# 75%      33.000000
# max      50.000000
# Name: Age, dtype: float64

# %%
male['Age'].describe()
# Out:
# count    104.000000
# mean      28.951923
# std        7.377978
# min       18.000000
# 25%       23.750000
# 50%       26.000000
# 75%       34.000000
# max       48.000000
# Name: Age, dtype: float64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
male['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Partnered    61
# Single       43
# Name: count, dtype: int64

# %%
female['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Partnered    46
# Single       30
# Name: count, dtype: int64

# %% [markdown]
# ### Exercício 7

# %%
df.corr
# Out:
# <bound method DataFrame.corr of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     TM195   18    Male         14        Single      3        4   29562.0
# 1     TM195   19    Male         15        Single      2        3   31836.0
# 2     TM195   19  Female         14     Partnered      4        3   30699.0
# 3     TM195   19    Male         12        Single      3        3   32973.0
# 4     TM195   20    Male         13     Partnered      4        2   35247.0
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   TM798   40    Male         21        Single      6        5   83416.0
# 176   TM798   42    Male         18        Single      5        4   89641.0
# 177   TM798   45    Male         16        Single      5        5   90886.0
# 178   TM798   47    Male         18     Partnered      4        5  104581.0
# 179   TM798   48    Male         18     Partnered      4        5   95508.0
#
#      Miles
# 0      112
# ...

# %%
df.cov
# Out:
# <bound method DataFrame.cov of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     TM195   18    Male         14        Single      3        4   29562.0
# 1     TM195   19    Male         15        Single      2        3   31836.0
# 2     TM195   19  Female         14     Partnered      4        3   30699.0
# 3     TM195   19    Male         12        Single      3        3   32973.0
# 4     TM195   20    Male         13     Partnered      4        2   35247.0
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   TM798   40    Male         21        Single      6        5   83416.0
# 176   TM798   42    Male         18        Single      5        4   89641.0
# 177   TM798   45    Male         16        Single      5        5   90886.0
# 178   TM798   47    Male         18     Partnered      4        5  104581.0
# 179   TM798   48    Male         18     Partnered      4        5   95508.0
#
#      Miles
# 0      112
# ...

# %% [markdown]
# ### Exercício 8

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Age'].plot(kind = 'hist', bins = 30)
plt.title('Histograma da idade dos clientes')
plt.xlabel('Idade')
plt.ylabel('Frequência');

# %%
df.hist(figsize = (12,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
df['Gender'].value_counts().plot(kind = 'pie');

# %% [markdown]
# ### Exercícios 9 - 13

# %%
df = pd.read_csv('datasets/dataset.csv')

# %%
df.index = range(1, df.shape[0]+1)
df
# Out:
#           Nome  Idade  Rating Renda
# 1         Sato     18    3.66     D
# 2       Suzuki     20    3.51     D
# 3    Takahashi     26    9.73     A
# 4       Tanaka     25    2.47     D
# 5     Watanabe     26    8.07     A
# ..         ...    ...     ...   ...
# 96      Matsuo     21    6.42     B
# 97     Kikuchi     18    7.91     A
# 98      Nomura     28    2.86     D
# 99        Arai     28    8.98     A
# 100   Watanabe     29    4.81     B
#
# [100 rows x 4 columns]

# %%
df.head(3)
# Out:
#         Nome  Idade  Rating Renda
# 1       Sato     18    3.66     D
# 2     Suzuki     20    3.51     D
# 3  Takahashi     26    9.73     A

# %%
df.tail(2)
# Out:
#          Nome  Idade  Rating Renda
# 99       Arai     28    8.98     A
# 100  Watanabe     29    4.81     B

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    100 non-null    str
#  1   Idade   100 non-null    int64
#  2   Rating  100 non-null    float64
#  3   Renda   100 non-null    str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#             Idade      Rating
# count  100.000000  100.000000
# mean    23.400000    5.625700
# std      4.042701    2.601318
# min     17.000000    1.150000
# 25%     20.000000    3.487500
# 50%     24.000000    5.890000
# 75%     27.250000    7.837500
# max     29.000000    9.990000

# %%
df.dtypes
# Out:
# Nome          str
# Idade       int64
# Rating    float64
# Renda         str
# dtype: object

# %%
df.isnull().sum()
# Out:
# Nome      0
# Idade     0
# Rating    0
# Renda     0
# dtype: int64

# %%
df['Idade'].describe()
# Out:
# count    100.000000
# mean      23.400000
# std        4.042701
# min       17.000000
# 25%       20.000000
# 50%       24.000000
# 75%       27.250000
# max       29.000000
# Name: Idade, dtype: float64

# %%
df['Idade'].corr(df['Rating'])
# Out:
# np.float64(-0.009929703930181348)

# %%
df['Idade'].cov(df['Rating'])
# Out:
# np.float64(-0.10442424242424238)

# %%
df['Renda'].value_counts()
# Out:
# Renda
# A    36
# B    31
# D    22
# E    11
# Name: count, dtype: int64

# %%
df.corr
# Out:
# <bound method DataFrame.corr of           Nome  Idade  Rating Renda
# 1         Sato     18    3.66     D
# 2       Suzuki     20    3.51     D
# 3    Takahashi     26    9.73     A
# 4       Tanaka     25    2.47     D
# 5     Watanabe     26    8.07     A
# ..         ...    ...     ...   ...
# 96      Matsuo     21    6.42     B
# 97     Kikuchi     18    7.91     A
# 98      Nomura     28    2.86     D
# 99        Arai     28    8.98     A
# 100   Watanabe     29    4.81     B
#
# [100 rows x 4 columns]>

# %%
df.cov
# Out:
# <bound method DataFrame.cov of           Nome  Idade  Rating Renda
# 1         Sato     18    3.66     D
# 2       Suzuki     20    3.51     D
# 3    Takahashi     26    9.73     A
# 4       Tanaka     25    2.47     D
# 5     Watanabe     26    8.07     A
# ..         ...    ...     ...   ...
# 96      Matsuo     21    6.42     B
# 97     Kikuchi     18    7.91     A
# 98      Nomura     28    2.86     D
# 99        Arai     28    8.98     A
# 100   Watanabe     29    4.81     B
#
# [100 rows x 4 columns]>

# %%
def escala_num(rating):
    if rating == 'E':
        return 1
    if rating == 'D':
        return 2
    if rating == 'B':
        return 3
    if rating == 'A':
        return 4

# %%
df['RendaNum'] = df['Renda'].apply(escala_num)

# %%
print('Correlação entre Rating e Renda')
df['Rating'].corr(df['RendaNum'])
# Out:
# Correlação entre Rating e Renda
# np.float64(0.9521213336056304)

# %%
df['Idade'].hist()
# Out:
# <Axes: >

# %%
df['Idade'].plot(kind = 'hist', bins = 20);

# %%
df['Idade'].plot(kind = 'box');

# %%
df_filt = df.query('Idade >= 28')

# %%
df_filt
# Out:
#           Nome  Idade  Rating Renda  RendaNum
# 18      Kimura     28    1.29     E         1
# 20     Shimizu     28    6.15     B         3
# 25   Hashimoto     29    4.57     B         3
# 30       Ogawa     28    6.07     B         3
# 33        Goto     28    8.30     A         4
# 36    Murakami     29    7.43     A         4
# 48     Matsuda     28    9.77     A         4
# 50      Nakano     29    8.97     A         4
# 52         Ono     29    1.50     E         1
# 54    Takeuchi     28    7.45     A         4
# 56        Wada     29    1.68     E         1
# 57    Nakayama     28    3.42     D         2
# 59        Ueda     28    5.92     B         3
# 62     Shibata     28    7.86     A         4
# 64    Miyazaki     29    2.22     D         2
# 65       Sakai     29    3.55     D         2
# 73   Taniguchi     28    6.11     B         3
# 76    Maruyama     28    1.98     E         1
# 83   Suguiyama     28    6.40     B         3
# ...

# %%
df_filt = df.query('Renda == "A"')

# %%
df_filt
# Out:
#          Nome  Idade  Rating Renda  RendaNum
# 3   Takahashi     26    9.73     A         4
# 5    Watanabe     26    8.07     A         4
# 6         Ito     25    7.25     A         4
# 10      Saito     21    8.63     A         4
# 11       Kato     18    9.34     A         4
# 12    Yoshida     24    7.83     A         4
# 13     Yamada     20    9.14     A         4
# 14     Sasaki     24    7.45     A         4
# 15  Yamaguchi     18    7.35     A         4
# 23      Ikeda     19    8.30     A         4
# 24        Abe     17    7.50     A         4
# 33       Goto     28    8.30     A         4
# 34   Hasegawa     22    8.43     A         4
# 36   Murakami     29    7.43     A         4
# 42  Nishimura     26    7.41     A         4
# 45      Miura     23    8.26     A         4
# 48    Matsuda     28    9.77     A         4
# 50     Nakano     29    8.97     A         4
# 53     Tamura     22    9.59     A         4
# 54   Takeuchi     28    7.45     A         4
# ...

# %%
df_filt = df.query('Rating > 5')

# %%
df_filt
# Out:
#          Nome  Idade  Rating Renda  RendaNum
# 3   Takahashi     26    9.73     A         4
# 5    Watanabe     26    8.07     A         4
# 6         Ito     25    7.25     A         4
# 7    Yamamoto     19    6.53     B         3
# 8    Nakamura     21    6.34     B         3
# 10      Saito     21    8.63     A         4
# 11       Kato     18    9.34     A         4
# 12    Yoshida     24    7.83     A         4
# 13     Yamada     20    9.14     A         4
# 14     Sasaki     24    7.45     A         4
# 15  Yamaguchi     18    7.35     A         4
# 20    Shimizu     28    6.15     B         3
# 23      Ikeda     19    8.30     A         4
# 24        Abe     17    7.50     A         4
# 27       Mori     25    5.31     B         3
# 28   Ishikawa     21    5.86     B         3
# 30      Ogawa     28    6.07     B         3
# 32      Okada     27    5.19     B         3
# 33       Goto     28    8.30     A         4
# 34   Hasegawa     22    8.43     A         4
# ...

# %% [markdown]
# ### Exercício 14

# %%
df = pd.DataFrame({'A': np.random.randint(1, 50, 10), 
                   'B': np.random.randint(1, 100, 10),
                   'C': np.random.randint(1, 250, 10),
                   'D': np.random.randint(1, 120, 10)
                  })

# %%
df.mean()
# Out:
# A     32.5
# B     51.8
# C    131.0
# D     37.2
# dtype: float64

# %%
from scipy.stats import gmean, hmean

# %%
geo_media= pd.DataFrame(gmean(df).reshape((4,1)).round(2),
                        index = list('ABCD'), 
                        columns = ['Média Geométrica'])

# %%
har_media = pd.DataFrame(hmean(df).reshape((4,1)).round(2), 
                         index = list('ABCD'), 
                         columns = ['Média Harmônica'])
a_media = pd.DataFrame(df.mean(), columns = ['Média Aritimética'])
 
medias = pd.concat(
    [a_media, geo_media, har_media],
    axis=1)

# %% [markdown]
# ### Exercício 15

# %%
df['A'].corr(df['B'])
# Out:
# np.float64(-0.09120570433767736)

# %%
df['C'].corr(df['A'])
# Out:
# np.float64(0.2835662027179262)

# %%
df.corr()
# Out:
#           A         B         C         D
# A  1.000000 -0.091206  0.283566  0.212968
# B -0.091206  1.000000 -0.337628 -0.509035
# C  0.283566 -0.337628  1.000000 -0.060542
# D  0.212968 -0.509035 -0.060542  1.000000

# %%
df.cov()
# Out:
#             A           B            C           D
# A  188.944444  -32.000000   278.111111   72.888889
# B  -32.000000  651.511111  -614.888889 -323.511111
# C  278.111111 -614.888889  5090.888889 -107.555556
# D   72.888889 -323.511111  -107.555556  619.955556

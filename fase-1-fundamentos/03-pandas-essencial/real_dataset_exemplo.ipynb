# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vamos utilizar esse dataset real para prever a partir dessas variáveis se um passageiro morreu ou não no acidente do titanic.
# Ja temos o dataset separado em treino e teste mas antes iremos analisar e limpar o dataset de treino

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando dataset

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
data = [train_df,test_df]
full_data = pd.concat(data)

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.shape
# Out:
# (891, 12)

# %%
test_df.shape
# Out:
# (418, 11)

# %%
full_data.shape
# Out:
# (1309, 12)

# %% [markdown]
# ### Inspecionando dataset

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# contar valores unicos por coluna
train_df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# aplicar a função para uma coluna em especifico
train_df['Embarked'].nunique()
# Out:
# 3

# %%
train_df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# Muda o dtype de uma coluna
train_df['Embarked'] = train_df['Embarked'].astype('category')
train_df['Embarked'].dtype
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False, categories_dtype=object)

# %%
train_df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
train_df['Survived'] = train_df['Survived'].astype('category')

# %% [markdown]
# ### Ordenação

# %%
# ordenando com valores numericos de uma dada coluna
df_ordenado = train_df.sort_values('Fare',ascending=False)
# Out:
#      PassengerId Survived  Pclass                                Name     Sex  \
# 258          259        1       1                    Ward, Miss. Anna  female
# 737          738        1       1              Lesurer, Mr. Gustave J    male
# 679          680        1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 88            89        1       1          Fortune, Miss. Mabel Helen  female
# 27            28        0       1      Fortune, Mr. Charles Alexander    male
# ..           ...      ...     ...                                 ...     ...
# 633          634        0       1       Parr, Mr. William Henry Marsh    male
# 413          414        0       2      Cunningham, Mr. Alfred Fleming    male
# 822          823        0       1     Reuchlin, Jonkheer. John George    male
# 732          733        0       2                Knight, Mr. Robert J    male
# 674          675        0       2          Watson, Mr. Ennis Hastings    male
#
# ...

# %%
# ordenar com colunas de string com os missing values por ultimo
train_df.sort_values('Cabin',ascending=False, na_position='last')
# Out:
#      PassengerId Survived  Pclass  \
# 339          340        0       1
# 394          395        1       3
# 205          206        0       3
# 251          252        0       3
# 10            11        1       3
# ..           ...      ...     ...
# 884          885        0       3
# 885          886        0       3
# 886          887        0       2
# 888          889        0       3
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Filtros

# %%
train_df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train_df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
train_df.query("Sex == 'male'").shape
# Out:
# (577, 12)

# %%
sex_male = train_df['Sex'] == 'male'
sex_female = train_df['Sex'] == 'female'

# %%
sex_female
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
train_df[sex_female]
# Out:
#      PassengerId Survived  Pclass  \
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 8              9        1       3
# 9             10        1       2
# ..           ...      ...     ...
# 880          881        1       2
# 882          883        0       3
# 885          886        0       3
# 887          888        1       1
# 888          889        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# duas ou mais condições
train_df[(train_df.Sex == 'female') & (train_df.Age >= 30)]
# Out:
#      PassengerId Survived  Pclass  \
# 1              2        1       1
# 3              4        1       1
# 11            12        1       1
# 15            16        1       2
# 18            19        0       3
# ..           ...      ...     ...
# 862          863        1       1
# 865          866        1       2
# 871          872        1       1
# 879          880        1       1
# 885          886        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# com query
train_df.query('(Sex == "male") & (Age >= 30) & (Embarked == "S")').index.to_list()
# Out:
# [4,
#  6,
#  13,
#  20,
#  21,
#  33,
#  35,
#  62,
#  70,
#  74,
#  92,
#  94,
#  99,
#  103,
#  104,
#  108,
#  110,
#  124,
#  129,
#  137,
#  148,
#  149,
#  150,
#  152,
#  153,
#  157,
#  160,
#  170,
#  178,
#  179,
#  187,
#  189,
#  197,
#  202,
#  206,
#  213,
#  217,
#  219,
#  222,
#  224,
#  232,
#  236,
#  239,
#  248,
#  249,
#  252,
#  253,
#  262,
#  263,
#  265,
#  286,
#  288,
#  314,
#  317,
#  326,
#  331,
#  332,
#  338,
#  339,
#  344,
#  349,
#  360,
#  363,
#  365,
#  382,
#  390,
#  397,
#  400,
#  405,
#  406,
#  414,
#  418,
#  429,
#  434,
#  438,
#  439,
#  447,
#  449,
#  450,
#  456,
#  460,
#  461,
#  462,
#  463,
#  465,
#  467,
#  471,
#  476,
#  482,
#  488,
#  492,
#  512,
#  515,
#  519,
#  528,
#  536,
#  543,
#  545,
#  548,
#  555,
#  561,
#  569,
#  570,
#  572,
#  579,
#  582,
#  586,
#  590,
#  592,
#  594,
#  595,
#  597,
#  603,
#  605,
#  606,
#  614,
#  616,
#  621,
#  625,
#  630,
#  631,
#  636,
#  637,
#  660,
#  662,
#  663,
# ...

# %% [markdown]
# ### Deletando linhas e colunas

# %%
df = train_df.copy()

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# axis = 0 -> linhas axis = 1 -> coluna
df.drop('PassengerId',axis=1, inplace=True)

# %%
df
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# ..       ...     ...                                                ...
# 886        0       2                              Montvila, Rev. Juozas
# 887        1       1                       Graham, Miss. Margaret Edith
# 888        0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889        1       1                              Behr, Mr. Karl Howell
# 890        0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# sepando dados em treino e teste ou seja separando a target das variaveis independentes
target = df['Survived']
X = df.drop(columns='Survived')

# %%
# deletando linhas por index
df.drop(index= 0)
# Out:
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# ..       ...     ...                                                ...
# 886        0       2                              Montvila, Rev. Juozas
# 887        1       1                       Graham, Miss. Margaret Edith
# 888        0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889        1       1                              Behr, Mr. Karl Howell
# 890        0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# filtrando uma condição pegando os indexs e apagando
rows = df.loc[df['Sex']=='male'].index.values

# %%
df.drop(rows,inplace=True)

# %%
df.shape
# Out:
# (314, 11)

# %%
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        314
# Sex           1
# Age          63
# SibSp         7
# Parch         7
# Ticket      247
# Fare        156
# Cabin        75
# Embarked      3
# dtype: int64

# %% [markdown]
# ### Renomeando colunas

# %%
colunas = {'Ticket': 'T'}
df.rename(columns=colunas)
# Out:
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..       ...     ...                                                ...
# 880        1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 882        0       3                       Dahlberg, Miss. Gerda Ulrika
# 885        0       3               Rice, Mrs. William (Margaret Norton)
# 887        1       1                       Graham, Miss. Margaret Edith
# 888        0       3           Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch                 T     Fare Cabin Embarked
# ...

# %%
# todas como lower
df.rename(columns=lambda coluna:coluna.lower())
# Out:
#     survived  pclass                                               name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..       ...     ...                                                ...
# 880        1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 882        0       3                       Dahlberg, Miss. Gerda Ulrika
# 885        0       3               Rice, Mrs. William (Margaret Norton)
# 887        1       1                       Graham, Miss. Margaret Edith
# 888        0       3           Johnston, Miss. Catherine Helen "Carrie"
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %% [markdown]
# ### Tratando missing data

# %%
# contar a quantidade de missing
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          53
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       217
# Embarked      2
# dtype: int64

# %%
# pra mostrar o percentual
(df.isna().sum()/df.shape[0])*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         16.878981
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       69.108280
# Embarked     0.636943
# dtype: float64

# %%
# pegar os valores nulos para uma determinada coluna
null_cabin = df['Cabin'].isnull()
df[null_cabin]
# Out:
#     Survived  Pclass                                               Name  \
# 2          1       3                             Heikkinen, Miss. Laina
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 14         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# ..       ...     ...                                                ...
# 875        1       3                   Najib, Miss. Adele Kiamie "Jane"
# 880        1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 882        0       3                       Dahlberg, Miss. Gerda Ulrika
# 885        0       3               Rice, Mrs. William (Margaret Norton)
# 888        0       3           Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# fazendo o contrario e pegando os valores nao nulos
notna_cabin = df['Cabin'].notna()
df[notna_cabin]
# Out:
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 31         1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# ..       ...     ...                                                ...
# 853        1       1                          Lines, Miss. Mary Conover
# 862        1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 871        1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879        1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887        1       1                       Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# ...

# %%
#Preenchendo missing values
df['Age'].fillna('Desconhecido')
# Out:
# 1              38.0
# 2              26.0
# 3              35.0
# 8              27.0
# 9              14.0
#            ...
# 880            25.0
# 882            22.0
# 885            39.0
# 887            19.0
# 888    Desconhecido
# Name: Age, Length: 314, dtype: object

# %%
df['Age'].median()
# Out:
# 27.0

# %%
# Preencher com a mediana
df['Age'].fillna(df['Age'].median())
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# 888    27.0
# Name: Age, Length: 314, dtype: float64

# %%
# Preencher com a media
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age          0.000000
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       69.108280
# Embarked     0.636943
# dtype: float64

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)

# %%
df['Cabin'].mode()[0]
# Out:
# 'G6'

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# Survived    0.000000
# Pclass      0.000000
# Name        0.000000
# Sex         0.000000
# Age         0.000000
# SibSp       0.000000
# Parch       0.000000
# Ticket      0.000000
# Fare        0.000000
# Cabin       0.000000
# Embarked    0.636943
# dtype: float64

# %% [markdown]
# ### Estatistica descritiva

# %%
df = train_df.copy()

# %%
# matriz de correlação entre as variaveis
corr = df.corr(numeric_only=True)

# %%
corr
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.036847 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age             0.036847 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp          -0.057527  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
# matriz de variancia e covariancia
df.cov(numeric_only=True)
# Out:
#               PassengerId     Pclass         Age      SibSp     Parch  \
# PassengerId  66231.000000  -7.561798  138.696504 -16.325843 -0.342697
# Pclass          -7.561798   0.699015   -4.496004   0.076599  0.012429
# Age            138.696504  -4.496004  211.019125  -4.163334 -2.344191
# SibSp          -16.325843   0.076599   -4.163334   1.216043  0.368739
# Parch           -0.342697   0.012429   -2.344191   0.368739  0.649728
# Fare           161.883369 -22.830196   73.849030   8.748734  8.661052
#
#                     Fare
# PassengerId   161.883369
# Pclass        -22.830196
# Age            73.849030
# SibSp           8.748734
# Parch           8.661052
# Fare         2469.436846

# %%
cov = df.cov()

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
varaveis = ['Age','Fare']
group1 = (df.groupby(by='Sex')[varaveis])
metricas = [np.mean,np.std,np.median,min,max]

# %%
# Agrupei os dados pelo sexo e a partir disso tirei as metricas focando nas duas colunas especificadas
group1.agg(metricas).T
# Out:
# Sex              female        male
# Age  mean     27.915709   30.726645
#      std      14.110146   14.678201
#      median   27.000000   29.000000
#      min       0.750000    0.420000
#      max      63.000000   80.000000
# Fare mean     44.479818   25.523893
#      std      57.997698   43.138263
#      median   23.000000   10.500000
#      min       6.750000    0.000000
#      max     512.329200  512.329200

# %%
varaveis = ['Age','Fare']
group2 = (df.groupby(by=['Sex','Survived'])[varaveis])
metricas = [np.mean,np.std,np.median,min,max]

# %%
group2.agg(metricas).T
# Out:
# Sex              female                    male
# Survived              0           1           0           1
# Age  mean     25.046875   28.847716   31.618056   27.276022
#      std      13.618591   14.175073   14.056019   16.504803
#      median   24.500000   28.000000   29.000000   28.000000
#      min       2.000000    0.750000    1.000000    0.420000
#      max      57.000000   63.000000   74.000000   80.000000
# Fare mean     23.024385   51.938573   21.960993   40.821484
#      std      24.821287   64.102256   32.409799   71.355967
#      median   15.245800   26.000000    9.416650   26.287500
#      min       6.750000    7.225000    0.000000    0.000000
#      max     151.550000  512.329200  263.000000  512.329200

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,annot = True,mask= mask,square=True,cmap='Blues')
# Out:
# <Axes: >

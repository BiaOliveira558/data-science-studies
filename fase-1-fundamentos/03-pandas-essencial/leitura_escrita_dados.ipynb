# %%
import pandas as pd

# %% [markdown]
# ### Exercício 1 - 4

# %%
df = pd.read_csv('datasets/distribuicao_respiradores_BR.csv',sep=';')

# %%
df.head(10)
# Out:
#          DATA FORNECEDOR         DESTINO ESTADO/MUNICIPIO        TIPO  \
# 0  19/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 1  22/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 2  08/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 3  08/05/2020        KTK  RIO DE JANEIRO           ESTADO         UTI
# 4  09/05/2020   LEISTUNG  RIO DE JANEIRO           ESTADO         UTI
# 5  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 6  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 7  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 8  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO  TRANSPORTE
# 9  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
#
#    QUANTIDADE    VALOR                                       DESTINATARIO  UF
# 0          40  2400000  ALMOXARIFADO ESTADUAL DE MEDICAMENTOS - RIO DE...  RJ
# ...

# %%
df.tail(3)
# Out:
#             DATA           FORNECEDOR DESTINO ESTADO/MUNICIPIO  \
# 1602  24/09/2020                  KTK  PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA  PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED  LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 1602             UTI           2    120000
# 1603  TRANSPORTE USA           1     63125
# 1604      TRANSPORTE         300  14487000
#
#                                 DESTINATARIO  UF
# 1602                           SMS de GUAIRA  PR
# 1603                           SMS de GUAIRA  PR
# 1604  MISSÃO FAB (Doação Destino ao Libano).   -

# %%
colunas = df.columns

# %%
print(colunas)
# Out:
# Index(['DATA', 'FORNECEDOR', 'DESTINO', 'ESTADO/MUNICIPIO', 'TIPO',
#        'QUANTIDADE', 'VALOR', 'DESTINATARIO', 'UF'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATA              1605 non-null   str
#  1   FORNECEDOR        1605 non-null   str
#  2   DESTINO           1605 non-null   str
#  3   ESTADO/MUNICIPIO  1605 non-null   str
#  4   TIPO              1605 non-null   str
#  5   QUANTIDADE        1605 non-null   int64
#  6   VALOR             1605 non-null   int64
#  7   DESTINATARIO      1605 non-null   str
#  8   UF                1605 non-null   str
# dtypes: int64(2), str(7)
# memory usage: 113.0 KB

# %%
df.dtypes
# Out:
# DATA                  str
# FORNECEDOR            str
# DESTINO               str
# ESTADO/MUNICIPIO      str
# TIPO                  str
# QUANTIDADE          int64
# VALOR               int64
# DESTINATARIO          str
# UF                    str
# dtype: object

# %%
df.shape[0]
# Out:
# 1605

# %%
df.isna().sum()
# Out:
# DATA                0
# FORNECEDOR          0
# DESTINO             0
# ESTADO/MUNICIPIO    0
# TIPO                0
# QUANTIDADE          0
# VALOR               0
# DESTINATARIO        0
# UF                  0
# dtype: int64

# %%
df['DATA'].head(3)
# Out:
# 0    19/04/2020
# 1    22/04/2020
# 2    08/05/2020
# Name: DATA, dtype: str

# %%
df['DATA'] = pd.to_datetime(df['DATA'], errors='coerce')
# Out:
# C:\Users\bob\AppData\Local\Temp\ipykernel_17820\2901336791.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['DATA'] = pd.to_datetime(df['DATA'], errors='coerce')

# %%
df['DATA'].head(3)
# Out:
# 0   2020-04-19
# 1   2020-04-22
# 2   2020-05-08
# Name: DATA, dtype: datetime64[us]

# %%
df['VALOR'].head(3)
# Out:
# 0    2400000
# 1    1200000
# 2    1500000
# Name: VALOR, dtype: int64

# %%
df['VALOR'] = df['VALOR'].astype(float)

# %%
df['VALOR'].head(3)
# Out:
# 0    2400000.0
# 1    1200000.0
# 2    1500000.0
# Name: VALOR, dtype: float64

# %%
df['FORNECEDOR'].unique()
# Out:
# <StringArray>
# [                              'VYAIRE',
#                              'MAGNAMED',
#                                   'KTK',
#                              'LEISTUNG',
#                       'LEISTUNG/VYAIRE',
#                            'KTK/VAYIRE',
#                                   'WEG',
#                   'VYAIRE LTV 2200 USA',
#                                   'UTI',
#                   'VYAIRE LTV 1200 USA',
#                   'MAGNAMED-REQUISIÇÃO',
#               'SUZANO/Zhongxun Medical',
#                         'SUZANO/Resmed',
#  'L C DADDE COM AT INST MAT MEDICO EPP',
#                   'MAGNAMED/REQUISIÇÃO',
#                              'Leistung']
# Length: 16, dtype: str

# %%
df['FORNECEDOR'].unique()
# Out:
# <StringArray>
# [                              'VYAIRE',
#                              'MAGNAMED',
#                                   'KTK',
#                              'LEISTUNG',
#                       'LEISTUNG/VYAIRE',
#                            'KTK/VAYIRE',
#                                   'WEG',
#                   'VYAIRE LTV 2200 USA',
#                                   'UTI',
#                   'VYAIRE LTV 1200 USA',
#                   'MAGNAMED-REQUISIÇÃO',
#               'SUZANO/Zhongxun Medical',
#                         'SUZANO/Resmed',
#  'L C DADDE COM AT INST MAT MEDICO EPP',
#                   'MAGNAMED/REQUISIÇÃO',
#                              'Leistung']
# Length: 16, dtype: str

# %%
df['TIPO'].unique()
# Out:
# <StringArray>
# ['UTI', 'TRANSPORTE', 'TRANSPORTE USA', 'Transporte']
# Length: 4, dtype: str

# %%
df['DESTINATARIO'].unique().size
# Out:
# 944

# %%
df.to_csv('datasets/distribuicao_respiradores-modificado.csv', index = False, sep = ';')

# %%
df.to_excel('datasets/distribuicao_respiradores-modificado.xlsx')

# %% [markdown]
# ### Exercício 5 - 6

# %%
df = pd.read_csv('datasets/CardioGoodFitness.csv',sep=',')

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head(3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
df.tail(2)
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 178    120
# 179    180

# %%
df.dtypes
# Out:
# Product            str
# Age              int64
# Gender             str
# Education        int64
# MaritalStatus      str
# Usage            int64
# Fitness          int64
# Income           int64
# Miles            int64
# dtype: object

# %%
df['Income'] = df['Income'].astype(float)

# %%
df.dtypes
# Out:
# Product              str
# Age                int64
# Gender               str
# Education          int64
# MaritalStatus        str
# Usage              int64
# Fitness            int64
# Income           float64
# Miles              int64
# dtype: object

# %%
df['Product'].unique()
# Out:
# <StringArray>
# ['TM195', 'TM498', 'TM798']
# Length: 3, dtype: str

# %%
df['MaritalStatus'].unique()
# Out:
# <StringArray>
# ['Single', 'Partnered']
# Length: 2, dtype: str

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
df.to_json('datasets/CardioGoodFitness.json')

# %% [markdown]
# ### Exercício 7

# %%
import requests

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')[1]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')[1]
#
# File c:\Users\bob\AppData\Local\anaconda3\envs\datascience\Lib\site-packages\pandas\io\html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
#    1232     skiprows=skiprows,
#    1233     parse_dates=parse_dates,
#    1234     thousands=thousands,
#    1235     attrs=attrs,
# ...

# %% [markdown]
# ### Exercício 8

# %%
df.to_csv('datasets/indcadores-USA.csv', sep = ';', index = False)

# %% [markdown]
# ### Exercício 9 - 10

# %%
df = pd.read_csv('datasets/FAOSTAT_data_12-5-2020.csv',sep=',')

# %%
df.head(5)
# Out:
#   Domain Code Domain  Area Code       Area  Element Code     Element  \
# 0          QC  Crops          9  Argentina          5419       Yield
# 1          QC  Crops          9  Argentina          5419       Yield
# 2          QC  Crops          9  Argentina          5419       Yield
# 3          QC  Crops          9  Argentina          5510  Production
# 4          QC  Crops          9  Argentina          5510  Production
#
#    Item Code    Item  Year Code  Year    Unit   Value Flag Flag Description
# 0        515  Apples       2016  2016   hg/ha  223912   Fc  Calculated data
# 1        515  Apples       2017  2017   hg/ha  235386   Fc  Calculated data
# 2        515  Apples       2018  2018   hg/ha  213072   Fc  Calculated data
# 3        515  Apples       2016  2016  tonnes  458908  NaN    Official data
# 4        515  Apples       2017  2017  tonnes  458908  NaN    Official data

# %%
df.shape
# Out:
# (66, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       66 non-null     str
#  1   Domain            66 non-null     str
#  2   Area Code         66 non-null     int64
#  3   Area              66 non-null     str
#  4   Element Code      66 non-null     int64
#  5   Element           66 non-null     str
#  6   Item Code         66 non-null     int64
#  7   Item              66 non-null     str
#  8   Year Code         66 non-null     int64
#  9   Year              66 non-null     int64
#  10  Unit              66 non-null     str
#  11  Value             66 non-null     int64
#  12  Flag              43 non-null     str
#  13  Flag Description  66 non-null     str
# dtypes: int64(6), str(8)
# memory usage: 7.3 KB

# %%
df.dtypes
# Out:
# Domain Code           str
# Domain                str
# Area Code           int64
# Area                  str
# Element Code        int64
# Element               str
# Item Code           int64
# Item                  str
# Year Code           int64
# Year                int64
# Unit                  str
# Value               int64
# Flag                  str
# Flag Description      str
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Flag Description']

# %%
col = ['Domain Code', 'Domain', 'Area Code', 'Element Code', 'Item Code', 'Year Code', 'Flag', 'Flag Description']
df.drop(columns=col, inplace=True, errors='ignore')

# %%
df.dtypes
# Out:
# Area         str
# Element      str
# Item         str
# Year       int64
# Unit         str
# Value      int64
# dtype: object

# %%
df = df.astype({'Value':float})

# %%
df.to_csv('datasets/FAOSTAT-modificado.csv', index = False)
